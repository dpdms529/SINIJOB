# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in d:\programs\lib\site-packages (1.0.2)

# %%
import pymysql
import pandas as pd

# %%
def db_connection():  # 데이터베이스 연결
    db = pymysql.connect(
        user='hanium',
        passwd='8bangwomen235!',
        host='haniumdb.caka4pfurzmq.ap-northeast-2.rds.amazonaws.com',
        port=3306,
        db='hanium',
        charset='utf8'
    )
    print("db connected")
    return db

# %%
def db_select_recruit(): # 공고 데이터 불러오기
    cursor = db.cursor(pymysql.cursors.DictCursor)
    
    try:
        sql = """select recruit_id from recruit where deleted = 0;"""
        cursor.execute(sql)
        results = cursor.fetchall()
        result = []
        for i in results:
            result.append(i['recruit_id'])
    except pymysql.err.internalError as e:
        code,msg = e.args
    finally:
        cursor.close()
        return result

# %%
db = db_connection()
# Out:
# db connected

# %%
result = db_select_recruit()

# %%
result_devided = []
length = len(result)
devided = length // 1000 + 1
start = 0
end = 999
for i in range(0, devided):
    temp = result[start:end]
    result_devided.append(temp)
    start = end
    end += 999
print(result_devided)

# %%
def db_select_detail(): #공고 상세정보 뽑아오기(공고 id, 공고 제목, 내용, 직종 이름, 요구 자격증)
    cursor = db.cursor(pymysql.cursors.DictCursor)
    data = []
    
    try:
        for result_list in result_devided:
            placeholders = ", ".join(["%s"] * len(result_list))
            sql = """select recruit.recruit_id, recruit.title, recruit.content, job_category.category_name, certificate.certificate_name from recruit inner join job_category
    on recruit.job_code=job_category.category_code left outer join recruit_certificate
    on recruit.recruit_id=recruit_certificate.recruit_id left outer join certificate
    on recruit_certificate.certificate_id=certificate.certificate_id
    where recruit.recruit_id in ({})""".format(placeholders)
            cursor.execute(sql, result_list)
            results = list(cursor)
            print(results)
            for j in results:
                data.append(j)
    except pymysql.err.InternalError as e:
        code,msg = e.args
    finally:
        cursor.close()
        return data

# %%
data = db_select_detail()
# Out:
# {'recruit_id': 'DdA0022108052040', 'title': '신림곰할인마트 오전(야채청과 판매 및 진열포장) 오후(계산대,배송) 심야(계산대)', 'content': '소형 마트내 상품진열 및 판매관리(검수)를 수행.\n\n시간, 임금조건 협의', 'category_name': '소규모 매장점장(매장매니저·매장슈퍼바이저)', 'certificate_name': None}
# {'recruit_id': 'DdA0402106172083', 'title': '외식업(F&B) 공유주방 지점 채용', 'content': '▶업무내용\r\n▷음식조리 (식자재관리)\r\n▷픽업데스크 (주문접수, 제품포장)\r\n▷POS관리 (포스피드, 오터, 포스페이스랩)\r\n\r\n▶근무장소\r\n▷용산 : 서울특별시 용산구 한강대로 324 1층 (숙대입구역 1번출구)\r\n▷역삼 : 서울특별시 강남구 테헤란로27길 23 지하1층 (역삼역 7번출구)\r\n▷신촌 : 서울특별시 서대문구 신촌로 127 신촌르메이르타운 지하2층 B201호 (신촌역 4번출구)\r\n▷영등포 : 서울특별시 영등포구 영중로 125 (영등포동8가, 롯데마트) 2층 (당산역 9번출구 // 영등포시장역 1번출구)\r\n*근무시간은 교대근무로 일8시간 근무', 'category_name': '한식 조리사(일반 음식점)', 'certificate_name': None}
# {'recruit_id': 'DdA0402107212110', 'title': '(강남구) 건물관리 사무직 모집', 'content': '사무보조, 회계보조, 건물관리', 'category_name': '분양·임대 사무원', 'certificate_name': None}
# {'recruit_id': 'DdA0402108062034', 'title': '상가 관리소장 모집', 'content': '상가 관리소장\n- 전기 및 수도검침\n- 관리단 회의 자료 작성\n- 2급 소방관리자\n- 기타 관리업무', 'category_name': '빌딩 관리소장', 'certificate_name': None}
# {'recruit_id': 'DdA3202106282333', 'title': '[자곡동] 3등급 할아버지 요양보호사님 구함', 'content': '[자곡동] 3등급 할아버지 요양보호사 : 어르신케어, 간단한 집안일, 식사준비        \r\n\r\n- 근무시간 : 주5일 근무 (13:00~16:00)     \r\n- 급여: 시급 11,000원        \r\n- 접수방법 : 채용담당자 전화 후 면접(010- 4311- 9615)', 'category_name': '재가 요양보호사', 'certificate_name': None}
# {'recruit_id': 'DdA3212108032025', 'title': '이수역인근 디오슈페리움2차 관리소장(주5일, 일근제) 채용합니다.', 'content': '- 주상복합아파트 관리소장업무.\r\n- 경력 3년이상 우대\r\n- 근무시간 09:00~18:00(휴게시간12:00~13:00).\r\n- 전기기사, 전기산업기사(무제안선임)이상 필수.\r\n- 이력서 팩스(031-388-8332), 이메일(ggaosil@naver.com)지원.', 'category_name': '아파트 관리소장', 'certificate_name': '전기기사'}
# {'recruit_id': 'DdA3212108032025', 'title': '이수역인근 디오슈페리움2차 관리소장(주5일, 일근제) 채용합니다.', 'content': '- 주상복합아파트 관리소장업무.\r\n- 경력 3년이상 우대\r\n- 근무시간 09:00~18:00(휴게시간12:00~13:00).\r\n- 전기기사, 전기산업기사(무제안선임)이상 필수.\r\n- 이력서 팩스(031-388-8332), 이메일(ggaosil@naver.com)지원.', 'category_name': '아파트 관리소장', 'certificate_name': '전기산업기사'}
# {'recruit_id': 'DdA3232106282099', 'title': '[자곡동/1등급 남자 어르신/긴시간] 요양보호사 모집', 'content': '- 모집직종 : [자곡동/1등급 남자 어르신/긴시간] 요양보호사 모집\n- 직무내용 : 70대 1등급 남자 어르신 케어(기저귀케어, 석션, 일상생활지원), 배우자와 함께 거주 중\n- 학력 및 경력사항 : 경력 6개월 이상\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 강남구 자곡로 101 래미안 강남힐즈\n- 근무시간 : 주5일 월-금요일 13:00 ~ 17:00(4시간)\n- 급여조건 : 시급 11,000원\n- 기타사항 : 요양보호사 자격증, 건강검진 기록', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232107162249', 'title': '[서초포레스타3단지/4등급 여자 어르신/오후] 요양보호사 모집', 'content': '- 모집직종 : [서초포레스타3단지/4등급 여자 어르신/오후] 요양보호사 모집\n- 직무내용 : 80대 4등급 여자 어르신 케어(청소 및 식사제공, 일상생활케어 등), 독거중이심. 거동가능.\n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 서초구 헌릉로8길 22 서초포레스타 3단지\n- 근무시간 : 주5일 월-금요일 13:00 ~ 16:00(3시간)\n- 급여조건 : 시급 11,100원', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232107302102', 'title': '[구룡역/3등급 여자 어르신/입주] 요양보호사 모집', 'content': '- 모집직종 : [구룡역/3등급 여자 어르신/입주] 요양보호사 모집\n- 직무내용 : 80대 3등급 여자 어르신 케어. 식사 및 반찬 제공. 병원 동행(택시로 이동하심). 배우자 계심. \n파킨슨병 질환자.\n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직\n- 근무예정지 : 서울시 강남구 개포로 403 (구룡역 인근)\n- 근무시간 : 입주(주6일)\n- 급여조건 : 월 3.200,000원\n- 기타사항 : 요양보호사 자격증, 건강검진 기록,', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232108022042', 'title': '[청계산입구역/2등급 남자 어르신/오전] 요양보호사 모집', 'content': '- 모집직종 : [청계산입구역/2등급 남자 어르신/오전] 요양보호사 모집\n- 직무내용 : 90대 2등급 남자 어르신 케어(기저귀케어, 욕창 체위변경, 식사먹여주기, 청소),와상환자\n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 서초구 헌릉로8길 45 서초포레스타 2단지\n- 근무시간 : 주5일 월-금요일 09:00 ~ 13:00(4시간)\n- 급여조건 : 시급 11,000원\n- 기타사항 : 요양보호사 자격증', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232108022267', 'title': '[대원비티에스,청담동] 빌딩 기계실 직원모집', 'content': '- 모집직종 : [대원비티에스,청담동] 빌딩 기계실 직원모집\n- 직무내용 : 빌딩 기계실 업무(전기 등 시설관리)\n- 학력 및 경력사항 : 고등학교 이상. 경력 1년 이상.\n- 고용형태 : 계약직 (기간 : 12개월)\n- 근무예정지 : 서울시 강남구 도산대로 541 (청담동) 세신빌딩\n- 근무시간 : 격일 09:00 ~ 09:00(휴게시간: 10시간)  \n- 급여조건 : 월 2,300,000원\n- 기타사항 : 전기기능사 자격증 필수', 'category_name': '빌딩 전기관리원', 'certificate_name': '전기기능사'}
# {'recruit_id': 'DdA3232108022267', 'title': '[대원비티에스,청담동] 빌딩 기계실 직원모집', 'content': '- 모집직종 : [대원비티에스,청담동] 빌딩 기계실 직원모집\n- 직무내용 : 빌딩 기계실 업무(전기 등 시설관리)\n- 학력 및 경력사항 : 고등학교 이상. 경력 1년 이상.\n- 고용형태 : 계약직 (기간 : 12개월)\n- 근무예정지 : 서울시 강남구 도산대로 541 (청담동) 세신빌딩\n- 근무시간 : 격일 09:00 ~ 09:00(휴게시간: 10시간)  \n- 급여조건 : 월 2,300,000원\n- 기타사항 : 전기기능사 자격증 필수', 'category_name': '빌딩 전기관리원', 'certificate_name': '전기기사'}
# {'recruit_id': 'DdA3232108042338', 'title': '[수서역/3등급 여자 어르신/오전] 요양보호사 모집', 'content': '- 모집직종 : [수서역/3등급 여자 어르신/오전] 요양보호사 모집\n- 직무내용 : 80대 3등급 여자 어르신 케어(청소 및 식사제공, 일상생활케어 등)따님과 같이 거주 중. 휠체어 이용 병원 동행.\n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 강남구 광평로 51길 49 수서1단지\n- 근무시간 : 주6일 월-토요일 10:00 ~ 13:00(3시간)\n- 급여조건 : 시급 11,400원\n- 기타사항 : 요양보호사 자격증', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232108062085', 'title': '[논현동/3등급 여자 어르신/오전] 요양보호사 모집', 'content': '- 모집직종 : [논현동/3등급 여자 어르신/오전] 요양보호사 모집\n- 직무내용 : 80대 3등급 여자 어르신 케어(신체활동지원, 가사 및 일상생활지원, 말벗 및 정서지원 등). 독거중이심. \n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 강남구 도산대로 38길 27 언북중학교 인근\n- 근무시간 : 주6일 월-토요일 09:00 ~ 12:00(3시간)\n- 급여조건 : 시급 11,200원\n- 기타사항 : 요양보호사 자격증,', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232108102229', 'title': '[세곡동/3등급 어르신/오후] 요양보호사 모집', 'content': '- 모집직종 : [세곡동/3등급 어르신/오후] 요양보호사 모집\n- 직무내용 : 80대 3등급 할머님 도움. 가족 거주(일하실 때 혼자 계심)\n- 학력 및 경력사항 : 무관\n- 고용형태 : 시간제\n- 근무예정지 : 서울시 강남구 자곡로36 (세곡동) 효성헤링턴코트아파트\n- 근무시간 : 주6일근무 월~토요일 14:00-17:00(3시간, 15 ~ 18시 가능)\n- 급여조건 : 시급 11,500원', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'DdA3232108122149', 'title': '[화곡동/4등급 여자 어르신/오후] 요양보호사 모집', 'content': '- 모집직종 : [화곡동/4등급 여자 어르신/오후] 요양보호사 모집\n- 직무내용 : 80대 4등급 여자 어르신 케어(파킨슨, 운동보조, 청소 및 식사제공 등)\n- 학력 및 경력사항 : 무관\n- 고용형태 : 상용직(시간제)\n- 근무예정지 : 서울시 강서구 화곡로13길 107 화곡 푸르지오 아파트\n- 근무시간 : 주5일 월-금요일 15:00 ~ 18:00(3시간)\n- 급여조건 : 시급 11,100원', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'K120032106160026', 'title': '정화조청소 미화원 모집', 'content': '-업무내용:  강남구청 정화조 청소 대행업체의 정화조 수거업무진행\r\n-입사제출서류: 이력서 제출, 건강검진 기록부', 'category_name': '환경 미화원', 'certificate_name': None}
# {'recruit_id': 'K120032106180039', 'title': '포천] 샴발라CC 골프장 코스관리부 그린모어 직원 채용', 'content': '모집부분 : 골프장 코스관리부 그린모어\r\n\r\n근무기간 : 골프장 시즌 오프까지(11월 말 예상)\r\n \r\n근무요일 : 주 6일 근무\r\n \r\n근무시간 : 03:00 ~ 11:00\r\n \r\n근무안내 : 골프장 그린관리 (그린모어)\r\n \r\n급여안내 : 일당 85,000원 계산하여 월급지급 (월 200~210만원 예상)\r\n \r\n우대조건 : 인근거주자 / 경력자', 'category_name': '조경원', 'certificate_name': None}
# {'recruit_id': 'K120032106180040', 'title': '용인] 화산CC 골프장 코스관리부 예초 담당 직원 채용', 'content': '모집부분 : 골프장 코스관리부 - 예초팀\r\n\r\n근무기간 : 장기 근속 가능자 모집\r\n \r\n근무요일 : 주 5일 근무 (월,화,수,목,금)\r\n \r\n근무시간 :(실 근무시간 짧으며, 휴게시간 2시간 이상)\r\n                출퇴근 차량 지원 (자차가능)\r\n                 예초 - 7:00 ~ 17:00\r\n\r\n근무안내 : 제초 - 잔디 풀뽑고, 다듬고 관리하는 업무\r\n                 예초 - 예초기로 잔디 관리하는 업무\r\n \r\n급여안내 : 예초 - 82,000원(주휴수당 별도지급 - 실급여 95,000원~100,000원 예상) \r\n\r\n우대조건 : 인근거주자 / 유사업무 경험자 / 셔틀차량 운행 예정', 'category_name': '조경 기술자', 'certificate_name': None}
# {'recruit_id': 'K120032106230055', 'title': '위례중앙타워 시설근무자(기계/전기/방재) 모집', 'content': '* 위례중앙타워(위례중앙광장 옆)에서 시설관리 근무자를 모집합니다. \r\n \r\n - 학력 : 학력무관\r\n\r\n - 경력 : 시설관리경력 최소 1년 이상\r\n     \r\n - 자격증  : 전기, 기계, 소방관련 기능사 이상 자격 보유자\r\n                 소방보조선임에 결격이 없는자   \r\n\r\n - 근무형태 : 3조 2교대(주주야야비비) 및 일근(주5일) / 순환근무\r\n\r\n - 급여 : 연봉 약 3000만원(연차 포함/퇴직금 별도)    \r\n\r\n - 주요업무 : \r\n    1) 건물 내 전기/기계/방재설비 관리\r\n    2) 건물 유지보수업무\r\n    3) 법정 면허 선임\r\n    4) 입주사 민원 처리\r\n    5) 기타 지시 업무 수행\r\n\r\n - 면접은 이력서 접수시 수시 진행(채용 완료 마감)', 'category_name': '건물 보수원 및 영선원(아파트 기계·전기 시설관리 제외)', 'certificate_name': None}
# {'recruit_id': 'K120032106230078', 'title': '홀서빙 (겸 주방세척)', 'content': '홀서빙, 그릇세척, 재료손질', 'category_name': '일반 음식점 서빙원', 'certificate_name': None}
# {'recruit_id': 'K120032107070033', 'title': '포천] 참밸리 골프장 코스관리부 볼마크(잔디복원)단순작업 직원 구인', 'content': '직무 - 골프공이 떨어지면서 파인 잔디 부분을 복원 · 정리하는 업무 등', 'category_name': '조경 식재원', 'certificate_name': None}
# {'recruit_id': 'K120032107090058', 'title': '4등급 남자어르신 (역삼역 인근)', 'content': '4등급 80대 중반 할아버님\r\n파킨슨 초기이며 거동가능하심\r\n\r\n신체활동지원( 걷기운동 함께해드리기), 말벗 , 목욕도움, 주변정리정돈\r\n\r\n오후 2시~5시 ( 3시간)\r\n오후 3시~6시도 가능', 'category_name': '재가 요양보호사', 'certificate_name': None}
# {'recruit_id': 'K120032107160003', 'title': '강원도 원주/횡성 동원썬밸리CC 골프장 예초 직원 모집', 'content': '예초기 활용하여 골프장 내 잔디(코스) 관리하는 업무', 'category_name': '농림어업 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120032107200048', 'title': '용인] 은화삼CC 골프장 코스관리부 잔디관리 예초 담당직원 채용', 'content': '예초팀 내 업무\r\n▶ 예초기 사용하여 골프장 잔디 깎는 업무 / 기타 일반관리', 'category_name': '조경 식재원', 'certificate_name': None}
# {'recruit_id': 'K120032107220035', 'title': '[부산센텀시티점] (주)쥬비스다이어트 일 4시간 근무 미화원채용(정규직전환가능)', 'content': '- 관리복, 수건 세탁 및 건조, 샤워실 청소 및 매장 청결유지 관리\r\n- 지점위생관리 등 주변환경정리', 'category_name': '기타 서비스 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120032107220041', 'title': '(의류) 우븐 생산관리', 'content': '담당업무\r\nㆍ의류 생산관리 (국내 및 해외)\r\n -  임가공 생산제품에 대한 품질관리\r\n지원자격\r\nㆍ경력 : 3 년 이상', 'category_name': '생산·품질 사무원 및 관리원(화학·섬유·의료)', 'certificate_name': None}
# {'recruit_id': 'K120032107270015', 'title': '[분당점] (주)쥬비스다이어트 미화원채용(정규직전환가능)', 'content': '- 관리복, 수건 세탁 및 건조, 샤워실 청소 및 매장 청결유지 관리\r\n- 지점위생관리 등 주변환경정리', 'category_name': '기타 서비스 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120032107270031', 'title': '건물경비', 'content': '건물 주차 경비', 'category_name': '경비원(건물 관리원)', 'certificate_name': None}
# {'recruit_id': 'K120032107270037', 'title': '[지파이브센트럴프라자/ 기계관리책임자] 산업기사 이상보유자/주당비 근무', 'content': '[지파이브센트럴프라자/ 주당비 근무] 서초동 복합상가 기계 책임관리자 모집-산업기사 이상보유자\r\n\r\n* 근무지 : 서울 서초구 서초동 1685-8번지 지파이브센트럴프라자  \r\n                (교대역 4번출구 도보 5분거리/ 지하 4층, 지상 5층 규모 빌딩)\r\n\r\n* 업무 : 기계관리 책임자. \r\n\r\n* 조건\r\n- 보일러, 공조냉동 등 관련 자격증 보유자 우선 채용\r\n- 기계기사 (보일러. 공조냉동 등). 산업기사 보유 후 10년이상 경력자\r\n- 연면적 3만㎡ 이상 건축물 경력 기계기사 경력. \r\n- 1천세대 이상 공동주택 기계기사 경력\r\n\r\n**기계설비유지관리자의 등급에 따른 자격 및 경력 기준** \r\n기술사 자격증      1)  보유시. -건축기계설비, 기계, 건설기계, 공조냉동기계, 산업기계설비, 용접기술사만 해당\r\n기능장 자격증      2)  7년이상 경력/ 자격증  - 배관, 에너지관리, 용접기능장만 해당\r\n기사    자격증      3)  7년이상 경력/ 자격증 -일반기계, 건축설비, 건설기계설비, 공조냉동기계, 설비보전, 용접, 에너지관리기사만 해당\r\n산업기사  자격증   4)  10년이상 경력/ 자격증 -건축설비, 배관, 건설기계설비, 공조냉동기계, 용접, 에너지관리산업기사만 해당\r\n건설기술인 --    5) (고급) 7년 이상 -공조냉동, 설비, 용접 전문분야만 해당(전문분야가 없을 경우, 등급 인정 불가)\r\n ※ 다만, ’21년 상반기 중 유지관리자 승급제도 도입에 따라 국가기술자격이 없더라도 경력, 학력 및 승급교육 평가 점수에 따라 상위 등급을 받을 수 있음\r\n\r\n가. 산업기사 보유\r\n나. 기능사 보유 및 실무경력 3년 이상\r\n다. ①인정기능사 보유 또는 ②기계설비기술자 중 유지관리자가 아닌 자  또는 ③기계설비 관련 학위 취득 또는 학과 졸업 및 실무경력 5년 이상\r\n\r\n* 급여/기타\r\n** 월 300 만원(세전)\r\n \r\n주당비 근무 \r\n- 주간 08:00~18:00 / 당직 08-:00~익일 08:00\r\n\r\n기타 : 식사제공, 퇴직금, 연차, 근무복 제공\r\n\r\n접수 : 워크넷.  이메일  \r\n          recruit2@proscom.co.kr   교대역 기계 책임자(교대제) 지원 표기.', 'category_name': '건물·가정용 냉동·냉장·공조기 설치·정비원', 'certificate_name': None}
# {'recruit_id': 'K120032107270055', 'title': '건설현장 경비원 모집 (태영 고양 향동)', 'content': '-태영건설 고양 향동 건설현장 경비업무\r\n-급여205만원\r\n-격일근무/복지카드소유자 우대\r\n*근무지주소:경기도 고양시 덕양구 향동동 391', 'category_name': '공사현장 경비원', 'certificate_name': None}
# {'recruit_id': 'K120032107280030', 'title': '용인] 은화삼CC 골프장 코스관리부 예초기 담당자 / 티예지 장비타실 분 모집', 'content': '◈ 예초팀원 내 업무\r\n    - 예초기 사용하여 골프장 그린(잔디) 가꾸는 업무\r\n    -추가로 근무자 출퇴근 픽업차량 운행 가능하신 분 우대 (차량 및 유류비 제공) - 일당 2만원 추가지급\r\n\r\n◈ 티예지 타실 분\r\n    - 티예지 타는 법 배워서 근무하실 분 (경력자 우대)', 'category_name': '조경 기술자', 'certificate_name': None}
# {'recruit_id': 'K120032107300063', 'title': '영업관리 구인', 'content': '주요업무  :  주류 영업 및 거래처 관리업무\r\n\r\n자격요건  :  학력 무관 , 경력 무관 \r\n\r\n우대사항  :  동종업계우대\r\n\r\n전형절차  :  서류전형 &gt; 1차면접 &gt; 임원면접 &gt; 최종합격', 'category_name': '배송·납품 운전원(납품영업 포함)', 'certificate_name': '자동차운전면허1종보통'}
# {'recruit_id': 'K120032108020051', 'title': '정수기 유지관리 및 A/S, 설치 직원 모집', 'content': '- 모집직종 : 정수기 유지관리 및 A/S, 설치 직원 모집\r\n- 직무내용 : 군부대, 단체, 기관 등 고객사 방문하여 정수기 A/S 설치, 관리 \r\n- 학력사항 : 고졸 이상\r\n- 경력사항 : 무관, 신입이어도 지원 가능\r\n- 고용형태 : 상용직\r\n- 근무시간 : 주5일근무 09:00-18:00\r\n- 급여조건 : 월평균 180만원~220만원, 면접후 협의\r\n- 우대조건 : 정수기 설치기사, 인근 거주자, 차량 소지자, 스타렉스 운전 가능자, 차량 유지비 제공', 'category_name': '정수기·냉온수기·비데 설치 및 수리원', 'certificate_name': '자동차운전면허1종보통'}
# {'recruit_id': 'K120032108050075', 'title': '포천] 참밸리 골프장 코스관리부 제초(풀뽑기) / 배토 직원 모집', 'content': '골프장 그린 잔디 관리\r\n\r\n- 풀뽑기 업무\r\n\r\n- 배토 (모래로 바닥을 관리하는 업무)', 'category_name': '농림어업 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120032108060021', 'title': '빌딩 보안원 채용 모집', 'content': '- 안양시 비산동\r\n- 인근거주자  우대.\r\n- 근무시간 : 2교대근무/ 08:00~익일 08:00 (근무시간8.5시간) 08:00~09:00,10:00~12:00,14:00~15:00,17:30~18:00,20:00~21:00,22:00~23:00,06:00~08:00 / 휴게시간 15.5시간\r\n- 급여 : 월급 1,300,000원(감단승인 받음)', 'category_name': '경비원(건물 관리원)', 'certificate_name': None}
# {'recruit_id': 'K120032108090011', 'title': '[진주 주간]출고보조 사원 모집', 'content': '-출고보조 및 현장보조(야적작업)', 'category_name': '하역·적재 종사원', 'certificate_name': None}
# {'recruit_id': 'K120032108090038', 'title': '수원공장 시설 관리자 모집', 'content': '[모집분야 및 자격요건]\r\n\r\n시설관리\r\n \r\n시설물 점검 및 유지보수\r\n \r\n학력: 학력무관\r\n경력: 경력2년↑ 우대\r\n\r\n[우대조건] \r\n장애인\r\n군전역간부(장교·부사관)\r\n자격증: 에너지관리기능사, 공조냉동기계기능사 \r\n\r\n\r\n[근무조건]\r\n근무지 : 경기 &amp;gt; 수원시 영통구 매영로 150(메탄동) /용인시 기흥구 인접\r\n교대근무: 5조 4교대근무 (주주야비)/ 4달은 4교대 근무, 1달은 일근\r\n근무시간 : (주간) 08시 00분 ~ 17시 30분\r\n               (야간) 17시 00분~ 7시30분 탄력근무제 가능\r\n급여 : 월급 230만원 ~ 240만원(면접 후 결정)\r\n \r\n\r\n[전형절차]\r\n\r\n서류전형 &amp;gt; 1차면접 &amp;gt; 2차면접 &amp;gt; 임원면접 &amp;gt; 최종합격 \r\n※ 면접일정은 추후 통보됩니다.\r\n(채용시마감)\r\n\r\n접수방법 : 워크넷 지원, 이메일 접수 \r\n제출서류 : 이력서, 자기소개서 제출', 'category_name': '건물·가정용 냉동·냉장·공조기 설치·정비원', 'certificate_name': '에너지관리기능사'}
# {'recruit_id': 'K120032108090038', 'title': '수원공장 시설 관리자 모집', 'content': '[모집분야 및 자격요건]\r\n\r\n시설관리\r\n \r\n시설물 점검 및 유지보수\r\n \r\n학력: 학력무관\r\n경력: 경력2년↑ 우대\r\n\r\n[우대조건] \r\n장애인\r\n군전역간부(장교·부사관)\r\n자격증: 에너지관리기능사, 공조냉동기계기능사 \r\n\r\n\r\n[근무조건]\r\n근무지 : 경기 &amp;gt; 수원시 영통구 매영로 150(메탄동) /용인시 기흥구 인접\r\n교대근무: 5조 4교대근무 (주주야비)/ 4달은 4교대 근무, 1달은 일근\r\n근무시간 : (주간) 08시 00분 ~ 17시 30분\r\n               (야간) 17시 00분~ 7시30분 탄력근무제 가능\r\n급여 : 월급 230만원 ~ 240만원(면접 후 결정)\r\n \r\n\r\n[전형절차]\r\n\r\n서류전형 &amp;gt; 1차면접 &amp;gt; 2차면접 &amp;gt; 임원면접 &amp;gt; 최종합격 \r\n※ 면접일정은 추후 통보됩니다.\r\n(채용시마감)\r\n\r\n접수방법 : 워크넷 지원, 이메일 접수 \r\n제출서류 : 이력서, 자기소개서 제출', 'category_name': '건물·가정용 냉동·냉장·공조기 설치·정비원', 'certificate_name': '공조냉동기계기능사'}
# {'recruit_id': 'K120032108090041', 'title': '(주)대한전기안전관리아이캔 직원모집', 'content': '전기안전관리대행', 'category_name': '빌딩 전기관리원', 'certificate_name': '전기산업기사'}
# {'recruit_id': 'K120032108090041', 'title': '(주)대한전기안전관리아이캔 직원모집', 'content': '전기안전관리대행', 'category_name': '빌딩 전기관리원', 'certificate_name': '전기기사'}
# {'recruit_id': 'K120032108090049', 'title': '경비원 구인', 'content': '- 아파트 경비로서 순찰 및 경비실 근무,\r\n- 경비신임교육이수 필수\r\n- 만60세 정년 후 1년단위 촉탁계약', 'category_name': '아파트·빌라 경비원', 'certificate_name': None}
# {'recruit_id': 'K120032108100038', 'title': '[급구]종로5가 오피스건물, 전기안전관리자 채용', 'content': '- 종로5가 한국기독교연합회관 시설부문 전기안전관리자(선임) 채용\r\n- 전기기사1급으로서 선임경력2년이상 혹은 \r\n  전기산업기사2급으로서 선임경력4년이상 되신분\r\n- 일반건물(오피스) 전기 설비 부문 유지관리\r\n- 일반건물(오피스) 기계설비 부문 운전 가능자 우대\r\n- 건물내외 각종 전기,기계설비,건축물 수선작업 지원\r\n- 일근 근무', 'category_name': '전기안전 기술자', 'certificate_name': '전기기사'}
# {'recruit_id': 'K120032108100038', 'title': '[급구]종로5가 오피스건물, 전기안전관리자 채용', 'content': '- 종로5가 한국기독교연합회관 시설부문 전기안전관리자(선임) 채용\r\n- 전기기사1급으로서 선임경력2년이상 혹은 \r\n  전기산업기사2급으로서 선임경력4년이상 되신분\r\n- 일반건물(오피스) 전기 설비 부문 유지관리\r\n- 일반건물(오피스) 기계설비 부문 운전 가능자 우대\r\n- 건물내외 각종 전기,기계설비,건축물 수선작업 지원\r\n- 일근 근무', 'category_name': '전기안전 기술자', 'certificate_name': '1급 소방안전관리자'}
# {'recruit_id': 'K120032108110019', 'title': '[세종조치원/2교대/주간] 3톤이상 지게차 운전원 채용', 'content': '*  3톤이상 지게차 운전원 채용 모집 \r\n- 근무예정지: 세종 조치원읍 번암공단 쌍용씨앤비 내 맨파워코리아\r\n1) 2교대 근무 : (주간) 7시~19시, (야간) 19시~7시\r\n2) 주간 근무 : 8시 ~ 17시(연장, 특근 발생 가능성 有)', 'category_name': '지게차 운전원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'K120032108120015', 'title': '[진주 주간]출고검수 사원 모집', 'content': '-출고보조 및 출고검수작업', 'category_name': '창고 관리원(자재 검수원 포함)', 'certificate_name': None}
# {'recruit_id': 'K120122107010031', 'title': '건축감리원모집', 'content': '복합체육시설 건축감리\r\n등급:중급기술자이상\r\n근무기간: 약 19개월\r\n연령관계없음:건강하신분\r\n감리보고서 컴퓨터작성가능자\r\n - 근무지: 강원도 삼척시 중앙로 346 감리현장 (교동) 출퇴근 가능자 우대\r\n - 문의: 02-3210-0455 정영동상무', 'category_name': '건축감리 기술자', 'certificate_name': None}
# {'recruit_id': 'K120122107090016', 'title': '동탄 센터포인트몰 미화원 모집', 'content': '- 제목 : 동탄 센터포인트몰 주간 미화원 모집\r\n - 모집부문 : 주간 미화원\r\n - 업무내용 : 오픈청소, 동선관리 /  화장실, 흡연실 관리 / 기계장비 운행\r\n - 자격요건 : 인근거주자 우대 / 밝고 성실하며 책임감이 강한 자 / 장기근무, 주말출근 가능자, 대근 근무 가능자\r\n - 근무시간 및 형태 : 07:00~15:00, 주5일 기준 휴무\r\n - 급여 : 171만원 (세금공제전), 특근비 , 식대지원비 1일 4,500원\r\n - 복리후생 : 4대보험, 퇴직금, 경조휴가, 명절선물\r\n - 근무지 : 경기 화성시 동탄중앙로 220 센터포인트몰\r\n - 지원방법 및 제출서류 : 온라인접수/유선문의\r\n - 마감일 : 채용시 까지\r\n - 연락처 : 강선규 소장(010-7632-0042) / dktlxkrk@naver.com', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120122107160023', 'title': '에너지진단 기술자 팀장,사원 모집', 'content': '** 에너지 진단 및 esco 업무(프로젝트 참여)\r\n\r\n- 에너지관리기사, 가스기사, 화공기사, 전기기사, 전기공사기사,\r\n   공조냉동기계기사, 건축설비기사 중 자격 기술자\r\n\r\n- 산업기사 및 기사 자격증 소지자 (필수)\r\n- 에너지진단 실무 경험자 (우대)\r\n\r\n- 운전면허증 소지자, 한글 워드 사용가능자', 'category_name': '건축안전·환경·품질·에너지관리 기술자', 'certificate_name': '에너지관리기사'}
# {'recruit_id': 'K120122107160023', 'title': '에너지진단 기술자 팀장,사원 모집', 'content': '** 에너지 진단 및 esco 업무(프로젝트 참여)\r\n\r\n- 에너지관리기사, 가스기사, 화공기사, 전기기사, 전기공사기사,\r\n   공조냉동기계기사, 건축설비기사 중 자격 기술자\r\n\r\n- 산업기사 및 기사 자격증 소지자 (필수)\r\n- 에너지진단 실무 경험자 (우대)\r\n\r\n- 운전면허증 소지자, 한글 워드 사용가능자', 'category_name': '건축안전·환경·품질·에너지관리 기술자', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120122107230002', 'title': '현장 근로자 채용', 'content': '1. 현장 단순노무\r\n선별된 플라스틱을 압축하여 정리 및 상차하는작업으로 \r\n압축기 기계조작 과 지게차로 압축물을 운반 정리 및 트럭에 상차하는 작업 \r\n\r\n\r\n2. 집게트럭 운행\r\n    거래처에서 벌크 플라스틱을 실어 운송하는 집게트럭 운전', 'category_name': '건설·채굴 기계 운전원', 'certificate_name': None}
# {'recruit_id': 'K120122107260022', 'title': '(부산/서구) 시멘트 회사 공무 경력자 채용', 'content': '생산/공무직\r\n* 우대사항: 시멘트 회사 유 경험자 또는 분말(비료등) 제품의 시설관리 유 경험자\r\n\r\n1. 공무(시설유지보수)\r\n  - 업무스킬\r\n  - 산소절단, 배관용접 가능자\r\n  - 부품교환 (모터, 베이링 (씰링작업 등), 실린더, 솔벨브 등)\r\n\r\n2. 생산\r\n  1) 시멘트 Silo별 재고관ㆍ리\r\n  2) mixer 장비 운전상태 확인\r\n  3) 전력량 검침 등등\r\n\r\n3. 출하\r\n  1) PLC 통신상태 확인\r\n  2) 마감 및 재고측정 등등\r\n\r\n4. 수하\r\n  1) 선박 접안 시간확인 및 설비가동상태 확인 (인터락)\r\n\r\n※ 삼표시멘트 1차 협력사로 연간단위로 계약갱신 가능\r\n *입사일로부터~21.12.31까지계약후 내년도 계속근무여부는 추후 협의됨\r\n *이력서, 자기소개서 워크넷입사지원이나 이메일지원하면 면접자개별통보합니다.\r\n   -이메일: mhkim@swservices.co.kr\r\n *문의: 070-4617-5675', 'category_name': '기타 공업기계 설치·정비원', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120122107270041', 'title': '디자인 및 인터넷신문 관리자 모집', 'content': '인터넷신문 관리, 신문출판 디자이너', 'category_name': '책·인쇄물·출판 디자이너', 'certificate_name': None}
# {'recruit_id': 'K120122107300016', 'title': '건축공무 담당', 'content': '건축 공무 업무 담당\r\n경력자 우대', 'category_name': '건축시공 기술자(건축견적, 공무포함)', 'certificate_name': '건축기사'}
# {'recruit_id': 'K120122107300016', 'title': '건축공무 담당', 'content': '건축 공무 업무 담당\r\n경력자 우대', 'category_name': '건축시공 기술자(건축견적, 공무포함)', 'certificate_name': '실내건축기사'}
# {'recruit_id': 'K120122108040006', 'title': '온라인 항공서비스  테스트 및 고객사 응대서비스', 'content': '온라인 항공서비스 연동 업체  문의 응대 및 서비스 테스트', 'category_name': '여행 사무원', 'certificate_name': None}
# {'recruit_id': 'K120122108040027', 'title': '주차 및 건물유지보수 등 시설관리 담당(고령자 채용)_주말근무 가능하신 분', 'content': '주차관리 및 건물 유지 보수 등 요양복지시설 관리 업무\r\n소방관리자 자격증 소지자 우대, 신체건강하신분 지원바랍니다\r\n*이력서제출\r\n팩스: 02-3217-2488\r\n이메일 : leech7936@naver.com\r\n문의 : 010-5074-7936\r\n* 주5일근무(주말근무필수) 평일휴무, 오전9시~오후6시근무 (주간 근무)\r\n* 고령자\r\n*월급183만원 (식사는 무료제공)\r\n* 채용후 건강검진결과, 주민등록등본 각 1통.', 'category_name': '기타 건물 관리원(공원, 종교시설 등)', 'certificate_name': None}
# {'recruit_id': 'K120122108060034', 'title': '금양운수(주) 용산04 마을버스 운전기사 모집', 'content': '마을버스 운전업무 (대형1종 보통, 버스운전자격증)\r\n-시내버스운전경력자 우대\r\n-마을버스운전경력 1년이상자\r\n-대형화물차 1년 이상자\r\n-26일근무시 제시된 급여. 근무일수에 따라 급여조정', 'category_name': '버스 운전원', 'certificate_name': '자동차운전면허1종대형'}
# {'recruit_id': 'K120122108060034', 'title': '금양운수(주) 용산04 마을버스 운전기사 모집', 'content': '마을버스 운전업무 (대형1종 보통, 버스운전자격증)\r\n-시내버스운전경력자 우대\r\n-마을버스운전경력 1년이상자\r\n-대형화물차 1년 이상자\r\n-26일근무시 제시된 급여. 근무일수에 따라 급여조정', 'category_name': '버스 운전원', 'certificate_name': '버스운전자'}
# {'recruit_id': 'K120122108090022', 'title': '광화문소재 사무실 7층 빌딩 미화원 모집', 'content': '빌딩 사무실 청소 (상가복도, 지정된 층 청소, 공용구역 청소, 여자화장실청소 등)\r\n※ 상세 근무시간\r\n- 인근거주자 우대 \r\n- 주5일근무 (월~금) (오전) 6시 00분~(오후) 1시 30분 근무 / 점심은 쌀제공. 반찬만 본인준비\r\n- 휴게시간: 08:00~10:00   휴게시간: 11:30~13:00 (휴게공간있음) \r\n- 토요일은 6주에 한번만 근무함 06:00~08:00 \r\n- 빌딩청소 경력 6개월이상 필수\r\n*이력서를 팩스나 이메일로 보내주시면 면접자 개별통보합니다\r\n  - 팩스: 02-3472-4215\r\n  - 이메일: moonyoung99@ naver.com', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120122108090053', 'title': '[광교 아브뉴프랑] 주차 유도원 모집', 'content': '▶ 주차 유도 안내 및 고객 응대 \r\n▶ 근무시간 : 11:00~21:00/12:00~22:00 (2교대근무) /(휴게시간) 조출 11:00~12:00 , 17:00~18:00\r\n                                                                                                        후출 15:00~16:00 , 18:00~19:00\r\n▶ 급 여 : 191만 원.\r\n▶연차 발생,퇴직금 발생,4대 보험,설.명절 선물', 'category_name': '주차 관리·안내원', 'certificate_name': None}
# {'recruit_id': 'K120122108100011', 'title': '요양보호사 선생님을 모십니다.', 'content': '입소 어르신 케어\r\n 1. 식사 제공 및 수발\r\n 2. 어르신 목욕\r\n 3. 일상 생활 수발 및 보조 \r\n*데이 : 07:00~15:10 (1개월간 10~11회)\r\n*이브닝 : 13:30~21:00 (1개월간 4~5회)\r\n*나이트 : 21:00~익일 09:00 (1개월간 4~5회)\r\n\r\n* 데이 또는 에스, 주, 야, 휴, 휴 또는 주주야야비비 ( + 추가 휴무 ) 형태의 2교대 선택 가능\r\n\r\n- 식사는 직원복지 차원에서 무료 제공 (식비 공제 또는 납부 없음)\r\n\r\n* 2021년부터 공휴일 대체 휴무 적용\r\n\r\n문의처: 010-5074-7936 대표', 'category_name': '시설 요양보호사(노인요양사)', 'certificate_name': '요양보호사'}
# {'recruit_id': 'K120122108100012', 'title': '요양보호사선생님을 모십니다.', 'content': '입소 어르신 케어\r\n요양보호사자격증 필수\r\n*1일 2교대 09:30~19:30 : 주간 2일, 19:30~익일09:30 : 야간 2일 근무후 2일 휴무, \r\n  스케쥴에 의해 6일 주기 교대 근무 및 휴무 (주주야야휴휴).\r\n* 공휴일 대체 휴일 적용, 스케쥴에 여유가 있으면 연차 외 추가 휴무 부여\r\n* 근무시간 중 식사는 무료 제공(별도 식비 공제 또는 납부는 없음)\r\n* 문의: 010-5074-7936.', 'category_name': '시설 요양보호사(노인요양사)', 'certificate_name': '요양보호사'}
# {'recruit_id': 'K120122108120007', 'title': '온산공단내 미화원 구인(세탁직원)', 'content': '온산공단내 미화원 구인(세탁기계 조작), 남자목욕탕에서 나온 세탁물 세탁하는 일이므로 신체건강하신분\r\n *세탁기계에 세탁물 세척 (휴게시간있음)\r\n근무장소 :  울산 울주군 온산읍 이진로 139(고려아연)\r\n근무시간 :  3조2교대(주간: 아침04:30~20:30/야간20:30~04:30/비번)\r\n                 주간휴게시간과 야간휴게시간시에 휴게공간별도있음 \r\n급여조건 : 세전 228만원(퇴직금,연차별도, 4대보험, 피복, 3식제공(조식,중식,석식제공))\r\n업무내용 : 근로자 피복 세탁기 및 건조기 투입, 분류 등 단순 노무작업\r\n지원자격 : 신체 건강한 자, 장기 근속 가능자\r\n지원방법 : 이메일 jinmyung-1@naver.com / fax 02-723-6771\r\n기타문의 : 미화소장 010-2564-7851', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142107020035', 'title': '동구 만석부두로 한국기초소재 청소원 모집', 'content': '* 업무 : 공장(한국기초소재) 내 미화업무, 물차운행(1톤포터), 보조업무등\r\n* 근무조건 : 08:00~17:00 (주5일)\r\n* 급여 : 월1,920,000원\r\n* 운전면허1종 필수/군필자/근거리 거주자 우대\r\n* 면접 필수', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142107120002', 'title': '롯데시네마 창원점 미화원 구인', 'content': '롯데시네마 창원관 오전/ 오후 미화 모집\r\n1.업무 시간 : 오전 : 17시 ~ 22시 (주 5일 근무(휴게시간 30분) / 평일 2일 휴무))\r\n2. 모집 인원 : 1명\r\n3. 기타 : 7월 ~ 8월까지 오후조 13시 00분 ~ 22시00분 \r\n    9월 부터 위 공고시간대로 5시간 근무.\r\n            (7-8월 임금 월160만원(세전), 휴게시간 2시간 / 9월 부터 월103만원(세전))', 'category_name': '청소원', 'certificate_name': None}
# {'recruit_id': 'K120142107120030', 'title': '소프트웨어 사업대가 및 기능점수 컨설턴트 모집', 'content': '[기능점수를 활용한 기능점수 측정 및 검증 업무]\r\n\r\n1) 소프트웨어(시스템) 규모 측정\r\n2) 소프트웨어 공수 측정\r\n3) 소프트웨어 적정사업기간 측정\r\n4) 소프트웨어 비용(예산) 측정\r\n5) 요구사항을 활용한 기능점수(FP_Function Point) 자동화 도구(FP-ACT) 관리\r\n6) 프로그램 소스를 활용한 기능점수(FP_Function Point) 자동 측정 도구 컨설팅\r\n7) 정보시스템 사업대가(규모, 비용, 공수, 기간 등) 측정 및 검증', 'category_name': 'JAVA 프로그래밍 언어 전문가', 'certificate_name': None}
# {'recruit_id': 'K120142107120035', 'title': '빌딩 사무실 미화원 반장 모집', 'content': '- 청소반장 경험자 우대\r\n- 빌딩(사무실) 청소 경험자 우대\r\n- 근면 성실한 분 우대.\r\n- 토 / 일요일 / 국공휴일  휴무', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142107130024', 'title': '[주5일/진위면]식품공장 미화원 모집', 'content': '업무내용\r\n - 월~금요일 06:30~15:30 오전 근무(조식,중식제공)\r\n - 공장내부 사무실, 복도, 회의실, 화장실 등 담당구역 청소 업무\r\n - 기타 제반 업무\r\n\r\n지원자격\r\n - 근면 성실하신분\r\n - 장기 근무 가능자\r\n - 신체 건강한 자\r\n - 동종업무(청소) 경험자\r\n - 자가용 출퇴근 가능자', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142107290016', 'title': '사무실칸막이 시공하실분 모집합니다', 'content': '칸막이 양중 및 칸막이 설치시공원', 'category_name': '건물칸막이 설치원', 'certificate_name': None}
# {'recruit_id': 'K120142108020036', 'title': '(주)행복찹쌀떡 떡제조 생산인력 구인', 'content': '찹쌀떡 제조 전반에 관한 업무\r\n\r\n 입고&gt;&gt; 검사&gt;&gt; 세척&gt;&gt; 증자&gt;&gt; 성형&gt;&gt; 포장&gt;&gt;출하 공정 중 단계별로 투입 되어 근무\r\n\r\n제조공정은 일반적인 떡집과 다르게, 식품제조공장이라고 생각하시면 됩니다. \r\n당사 공장은 HACCP 적용사업장으로 깨끗하고, 안전한 환경에서 근무하시게 됩니다. \r\n업무를 수행하는데 특별히 요구 되는 능력은 없으나, 공동 작업이므로, 다른 사람과 조화롭게 근무할 수 있어야 합니다.\r\n떡류 제조공장의 특성 상 아침 일찍 작업이 시작 되나, 휴게 시간을 적절히 배치하여, 현재 고령자 직원들도 원활하게 근무하고 계십니다.', 'category_name': '떡 제조원(한과 포함)', 'certificate_name': None}
# {'recruit_id': 'K120142108020053', 'title': '글로리서울안과 소비자 홍보 모니터링 요원 1기 모집', 'content': '이런 사람 추천해요~!\r\n밝은 마인드를 가진 함께 즐겁고 보람있게 활동하실 분\r\n적극적이고 5060시니어 분들과의 소통에 자신있는 분\r\n\r\n1. 모집 기간\t\t\t\t\t\r\n 2021년 8월 31일까지\t\t\t\t\t\r\n\t\t\t\t\t\r\n2. 모집 인원 : 00명\t\t\t\t\t\r\n\t\t\t\t\t\r\n3. 활동 기간\t\t\t\t\t\r\n 2021년 9~11월 (3개월)\t\t\t\t\t\r\n\t\t\t\t\t\r\n4. 활동 내용\t\t\t\t\t\r\n 눈건강지킴이 홍보 활동\t\t\t\t\t\r\n _눈건강캠페인, 눈검진 필요성, 안과관련 병원 정보 제공 등\t\t\t\t\t\r\n 수요/설문조사 마케팅 활동\t\t\t\t\t\r\n\t\t\t\t\t\r\n5. 활동 혜택\t\t\t\t\t\r\n 활동비 지급 \t\t\t\t\t\r\n    -월 150만원 ( 1일 7만원 * 20일/월 근무 기준+교육 이수 10만원) \t\t\t\t\t\r\n 평가에 따른 정규직 전환 채용\t\t\t\t\t\r\n\t\t\t\t\t\r\n6. 교육 의무\t\t\t\t\t\r\n 활동 기간 내 주 2회씩 정기 교육 및 활동 평가 참여\t\t\t\t\t\r\n\t\t\t\t\t\r\n7. 전형 절차\t\t\t\t\t\r\n 1차 전형(서류) → 2차 전형(면접 및 설명회) → 최종합격 → 오리엔테이션\t\t\t\t\t\r\n \t\t\t\t\t\r\n8. 전형방법\t\t\t\t\t\r\n 가. 1차 전형(서류)\t\t\t\t\t\r\n  - 제출서류 : 이력서 (+자기소개서)\t\t\t\t\t\r\n  - 온라인 지원 : dolljoo@naver.com 이메일 접수\t\t\t\t\t\r\n 나. 2차 전형(면접)\t\t\t\t\t\r\n  - 1차 전형 합격 후 추후 안내', 'category_name': '고객 상담원 및 모니터 요원', 'certificate_name': None}
# {'recruit_id': 'K120142108040031', 'title': '[강동역/오전] 미화원 모집', 'content': '- 문의사항은 문자로 문의바라고,\r\n  이력서 제출하시면 면접대상자 개별 연락합니다.\r\n\r\n1. 모집 분야: 미화원\r\n\r\n2. 담당업무\r\n  - 청소원의 업무\r\n  - 미화원의 업무\r\n  - 회의실, 임원실, 탕비실, 화분, 유리Wall\r\n  - 공용회의실 공간 관리범위 내 쓰레기 분리수거 등\r\n\r\n3. 자격조건\r\n  - 관련 경력 1년 이상 경력자\r\n  - 책임감, 성실함 등을 가지고 있는 자\r\n\r\n4. 우대사항\r\n  - 인근 거주자(출퇴근 가능자)\r\n  - 유사직종 경력자\r\n\r\n5. 근무조건\r\n  - 주5일제 근무 (오전 6시~오전 10시까지)  / 시간 협의 가능\r\n \r\n6. 급여조건\r\n  - 월 약 1,007,240원(기본급: 911,240원+식대50,000원+연차수당46,000원)\r\n  - 복리후생: 4대보험, 퇴직금 별도, 근무복 지급', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142108040039', 'title': '(장애인채용) 미화직 채용', 'content': 'ㅇ직무내용: 사무실 청소, 냉장고 정리, 회의실 청소\r\nㅇ근무지: 서초구 강남대로 343, 선덕빌딩 3층(강남역 5번 출구)\r\nㅇ고용형태: 계약직 6개월  (6개월 근무 후, 평가에 따라 장기근속 가능)\r\nㅇ업무강도: 약함 (건물소속 청소하시는 분 별도 상주하고 있음)\r\nㅇ급여: 시급 10,000원\r\nㅇ근무시간: 월-금요일 07:00 - 10:00 (일 3시간, 협의가능)', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142108050019', 'title': '방배그린마트 경리(캐셔).배송직원.농산직원', 'content': '매장내에서 고객과의 계산업무 처리후 마감 \r\n매장 사무실 경리직\r\n매장 판매상품 배송업무', 'category_name': '대형마트 판매원', 'certificate_name': '원동기운전면허'}
# {'recruit_id': 'K120142108050021', 'title': '[인천]유진레미콘 인천공장 미화원 모집', 'content': '레미콘 공장 사무실 및 화장실 건물청소\r\n마당청소(바닥모래 물청소 후 삽으로 정리)\r\n몰드청소(분유깡통크기 시멘트 틀 청소)\r\n주 5일 근무\r\n08:00 출근 ~ 17:00 퇴근 (점심시간 11:30~12:00)', 'category_name': '청소원', 'certificate_name': None}
# {'recruit_id': 'K120142108060015', 'title': '쿠팡 천안1캠프  미화/방역인원 긴급 구인 (주말 오후)', 'content': '모집부문\r\n모집분야\t담당업무 및 자격요건\r\n쿠팡 캠프지\r\n청소 및 방역 사원\t≪담당업무≫\r\n*캠프내 청소 및 방역 업무\r\n\r\n≪자격요건≫\r\n- 초보가능 / 남녀무관\r\n- 장기근무 가능자 우대\r\n- 관련업무 경험자 우대\r\n- 즉시 출근 가능자 우대\r\n근무조건\r\n    근무기간 : 3개월~6개월 이상 (협의가능)\r\n   ★장기근무 희망자 우대★\r\n\r\n- 근무시간 :  오후 15:30 ~ 22:00 (일 6h 근무, 휴게 30분 별도)\r\n- 근무요일 : 주말( 토,일)\r\n- 주 근무일수 : 2일\r\n- 급여조건 : 월 460,000원\r\n\r\n\r\n\r\n- 급여지급일 : 매월 1일~말일 근무시 익월 15일 지급\r\n\r\n\r\n근무지 : 충청남도 천안시 서북구 차암동 16-16\r\n \r\n \r\n★타캠프 근무이력여부 확인★\r\n쿠팡이츠 : 14일 이내 근무불가 / 15일 이상부터 가능\r\n타캠프 헬퍼 및 플렉스 : 5일 이내 근무불가 / 6일 이상부터 근무가능\r\n \r\n \r\n 미성년자 불가능\r\n교통편이 어려우므로 자차로 출퇴근 가능자 우대\r\n\r\n※ 각 캠프별 사정에 따라 로테이션 근무가 있을 수 있습니다!\r\n접수방법\r\n접수방법 : 문자지원  010-3898-5915\r\n \r\n** 문자지원 부탁드립니다. 전화통화 어려울 수 있습니다. 문자주시면 연락드립니다.\r\n \r\n이름/나이/성별/희망근무기간/쿠팡 OO캠프 청소,방역 지원]-&amp;gt; 기재하여 문자 지원!!\r\n\r\n\r\n** 약속 꼭 지키실 수 있는 분만 지원부탁드립니다', 'category_name': '환경미화원 및 재활용품 수거원', 'certificate_name': None}
# {'recruit_id': 'K120142108090019', 'title': '[야탑동]바른세상병원 보안요원 채용', 'content': '야탑 바른세상 병원 보안요원\r\n-월~금 09:00~18:00 \r\n-휴게시간 1시간30분\r\n\r\n-토요일 09:00 ~ 13:00 \r\n- 휴게시간 30시간\r\n\r\n-월 2,000,000원\r\n-아침, 점심 제공', 'category_name': '기타 경호·보안 종사원', 'certificate_name': None}
# {'recruit_id': 'K120142108090031', 'title': '[ 다산동 ] 철근콘크리트 현장 형틀총무구함', 'content': '/ 건설현장 총무직구함(철콘업체)\r\n- [건축&amp;gt;건축시공&amp;gt;철근콘크리트시공]\r\n- 현장 자재관리, 용역관리, 전반적인 현장 업무 수행\r\n- 주6일근무 (07~17시, 350~400만원-초과근무수당 일체 포함)', 'category_name': '건설·채굴 단순 종사원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'K120142108090054', 'title': '[인천 숭의역 도원역인근/ 주5일]현대유비스병원 병동식당 조리원 채용', 'content': '* 현대유비스병원 병동식당 조리원 채용\r\n- 업체 급식 조리업무 \r\n- 근무시간 : 스케줄 근무 2교대\r\n- 급여 : 월221만원\r\n- 근무조 : A조 05:00~15:00 B조 10:00~20:00 \r\n- 근무요일 : 주5일 스케쥴근무', 'category_name': '사업체 구내식당 급식 조리사', 'certificate_name': None}
# {'recruit_id': 'K120142108100002', 'title': '[급구] 지게차 기사님 모집', 'content': '주간 근무 (08:30~17:30)\r\n지게차 자격증 필수\r\n- 휴일근무, 시간외 근무 있을 수 있으며, 시간외 수당 별도 지급', 'category_name': '지게차 운전원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'K120142108100020', 'title': '건물 경비원 모집', 'content': '건물 단순 보안 경비.\r\n격일제 맞교대', 'category_name': '건물 경비원(청사,학교,병원,상가,빌딩,공장 등)', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120142108110014', 'title': '송파구 잠실한주빌딩 미화원 구인', 'content': '1)근무형태 \r\n - 주6일제\r\n - 08:00 ~ 16:30 (월~금) 휴게시간 2시간\r\n - 08:00 ~ 12:00 (토요일)\r\n\r\n2)급여\r\n - 월 175만원\r\n\r\n3)특이사항 : 가. 인근거주자 우대\r\n                    나. 미화 경력 5년 이상\r\n                    다. 성실하고 서비스마인드 좋으신 분', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'K120142108120005', 'title': '유통업 물류에 적합한 인재를 찾습니다(자재사무원)', 'content': '- 자재 구매, 재고관리 등\r\n\r\n자재 입,출고 작업하기 \r\n자재 입,출고 검사하기\r\n자재 입,출고 계획 수립하기 \r\n자재 입,출고 방법 설정하기 \r\n\r\n공정재고 기준 확인하기 \r\n자재 공급회수 방법 선정하기 \r\n\r\n자재 보관 조건 설정하기 \r\n자재 보관위치 관리하기 \r\n\r\n창고 동선 관리하기 \r\n창고 보관 효율 관리하기 창고 보안 안전 관리하기', 'category_name': '자재·구매·물류 사무원', 'certificate_name': None}
# {'recruit_id': 'K120232106300027', 'title': '[장애인채용/워크넷 지원불가] 케이씨에코사이클(주) 재활용품 선별직 정규직 채용', 'content': '○ 근무시간: 주5일  8시~18시 \r\n * 8시간 근무, 2시간 휴게시간(휴게 30분씩 2회, 점심시간 1시간)  \r\n * 주5일근무, 중식 제공 \r\n○ 직무내용 : 재활용품(비닐, 파지) 선별직 \r\n○ 지원자격 : 서서 근무가 가능한분. 5kg이내 재활용품 분류작업 후, 20kg 이내 마대를 옮기는 작업이 가능하신 분 \r\n○ 모집인원: 2명 \r\n○ 고용형태:  정규직', 'category_name': '재활용품 및 폐기물 수거원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'K120232107130026', 'title': '편의점 판매사원 모집', 'content': 'ㅇ 편의점 상품판매\r\nㅇ 카운터, 진열, 재고관리 등', 'category_name': '편의점 판매원', 'certificate_name': None}
# {'recruit_id': 'K120232107140017', 'title': '[문정동]경리(회계)및 총무담당 직원 모집', 'content': '*경리(회계)및 총무업무 담당 직원 모집\r\n주5일근무(09:00~18:00)\r\n연봉2,500~2,900만원(면접후협의),중식제공\r\n컴퓨터활용능력우수자,회계프로그램 더존사용가능자 우대\r\n\r\n*지원방법:이메일(youngga22@naver.com)', 'category_name': '경리 사무원(제조)', 'certificate_name': None}
# {'recruit_id': 'K120232107300004', 'title': '서울동부지방법원 공무직근로자(환경관리원) 채용 공고/자체 이력서 양식있음', 'content': '1. 법원 청사 내·외부 청소(외부1층 유리창, 주차장, 승강기 등) \r\n2. 제설작업(인도, 옥상, 지하주차장 등) \r\n3. 왁스 등 기계작업 및 카페트 바닥 청소 \r\n4. 청소물 처리(쓰레기 처리, 기구를 이용한 낙엽정리 등) \r\n5. 기타 환경 미화 작업 등 기관장이 지정하는 업무 \r\n\r\n서울동부지방법원 홈페이지(https://sldongbu.scourt.go.kr) 소식- 새소식 란 공무직 근로자 채용공고문 및 붙임서류 참고하여 지원하여 주시기 바랍니다.', 'category_name': '환경미화원 및 재활용품 수거원', 'certificate_name': None}
# {'recruit_id': 'K120232108040001', 'title': '에콜리안 거창골프장 경기진행 임시계약직 모집 공고', 'content': '골프장 경기진행\r\n- 고객안내\r\n- 카트운전, 카트청소, 코스 내 경기 진행 업무 등 (단순업무)\r\n\r\n* 회사사정에 따라 채용예정일이 변경 될 수 있음\r\n\r\n1. 모집분야  \r\n - 경기진행분야 : 1명 / 경기진행보조, 홀설명, 고객 안전관리 \r\n - 주말근무(토요일, 일요일) 및 주중 시간제 근무 가능\r\n\r\n2. 근무기간  \r\n- 경기진행분야 : 2개월 (주5일 / 1개월 단위 근로계약서 작성)\r\n  * 근무일은 현장사정에 따라 조정 가능\r\n\r\n3. 근무시간  \r\n - 경기진행분야  04:30~13:30, 07:00~16:00, 10:30~19:30 조출, 중출, 후출 근무계획표에 따라 시간조정\r\n * 출퇴근 시간은 현장여건에 따라 협의 가능\r\n\r\n4. 자격기준   \r\n - 경기진행분야 : 경력무관 (시급 8,720원) \r\n * 성범죄 및 아동학대 관련 범죄 사실이 없는 자, 조회 동의서 필요 \r\n * 공휴일(공휴수당 지급), 주말 근무 가능자\r\n * 백신접종 증명서 혹은 코로나검사결과서 (음성확정문자) 필요\r\n\r\n5. 근무형태  - 기간의 정함이 있는 임시계약직 \r\n\r\n6. 전형일정 \r\n○지원서 접수 2021.8.3 (화) ~ 2021.8.10(화) 14:00 마감 \r\n○채용심사(서류) 2021.8.11 (수) \r\n○서류 합격자 발표 2021.8.11 (수) 합격자 개별 통보 \r\n○채용심사(면접) 2021.8.12 (목) (에콜리안 거창 골프장 경기진행 사무실)  \r\n○합격자 발표 2021.8.13 (금) 합격자 개별 통보\r\n○채용 예정일 2021.8.14 (토) \r\n\r\n  * 회사 사정에 의해 채용예정일 변경 가능.', 'category_name': '골프장 캐디', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120232108050032', 'title': '2021년 상반기 공동주택 하자보험금 청구영업직 공개모집', 'content': '1. 기술정규직 대우 및 직무내용\r\n\r\n  1)연봉 : 3,000만원~4,000만원 상여금 포함\r\n\r\n  2)직무내용 \r\n   경력직은 안전진단기관으로써 건축물에 대한 안전점검 또는 안전진단, 법원감정에 필요한 하자감정, 하자조사, 건축\r\n   물 공사 관련 피해조사 등의 업무.\r\n\r\n\r\n2. 하자보험금 청구 영업직 대우 및 직무내용\r\n\r\n 1)하자보험금청구 영업직 직무내용\r\n   입주자 및 입주자대표회의(관리단) 미팅 / 수주계약체결 / 하자조사 / 하자사진정리\r\n \r\n  2)대우\r\n   하자보험금청구 영업직(하자보험금 청구 영업직)은 인센티브 수당을 책정하여 지급합니다.', 'category_name': '기술 영업원', 'certificate_name': None}
# {'recruit_id': 'K120232108090027', 'title': '성실하신 병원 식당 주방보조 구인', 'content': '[모집내용] \r\n- 업무내용 : 성실하신 병원 식당 주방보조구인 \r\n- 근무유형 : 정규직(정직원) \r\n- 근무요일 : 주5일 (주말 근무 있음) \r\n- 근무시간 : 09:30 ~ 18:30 , 05:30 ~ 14:30 (스케줄에 따라 조정) \r\n- 급 여 : 월급 1,950,000원 ~ 1,950,000원 \r\n\r\n[복리후생] \r\n- 국민연금,건강보험,고용보험,산재보험,퇴직금,휴일수당,연차,생일지원금\r\n\r\n[우대·가능] \r\n- 인근거주자 \r\n\r\n[접수방법] \r\n- 접수방법 : 온라인지원, 이메일지원, 전화지원', 'category_name': '주방 보조원', 'certificate_name': None}
# {'recruit_id': 'K120232108110015', 'title': '병원에서 근무하실 주방 조리 보조  모십니다(주 3일 근무).', 'content': '입원환자 및 직원 식사 조리(보조)', 'category_name': '단체 급식 보조원', 'certificate_name': None}
# {'recruit_id': 'K120252106250014', 'title': '제주 특급리조트 룸메이드 모집', 'content': '제주 특급리조트에서 룸메이드를 모집합니다.\r\n\r\n&lt; 근로시간 및 조건 &gt;\r\n근로지 : 제주도 한림읍 귀덕리 3861 켄싱턴리조트 한림\r\n직무명 : 룸메이드\r\n근로조건 : 월 7 회휴무 (08:30~17:00)\r\n휴게시간 : 1시간(12~13시)\r\n\r\n급여 : 200만원 이상(중식제공/ 추가방 수당별도)\r\n\r\n장기 근무하실 분 우대합니다.', 'category_name': '호텔·콘도·숙박시설 청소원(룸메이드,하우스키퍼)', 'certificate_name': None}
# {'recruit_id': 'K120252107020016', 'title': '물류센터 직원 [식사 제공 / 셔틀운행]', 'content': '* 담당업무\r\n1. 물류\r\n-입/출고, 반품 처리\r\n-포장 등의 단순 노무\r\n\r\n2. 품질\r\nㆍ조립 및 AS 업무\r\nㆍ스핀바이크 , 폴민바이크, 워킹머신 등에 대한 수리 \r\nㆍ반품 상품에 대한 교체/수리 \r\n\r\n* 근무조건\r\n-근무형태\t: 3개월 수습 후 정규직 , 계약직 무관\r\n-근무일시\t: 주 5일(월~금) 오전 9시~오후 6시\r\n-급여        : 월급 215만원 ~ 235만원 (면접 후 결정)\r\n-근무지역\t: 경기 포천시 일동면 유동리\r\n\r\n복리후생\r\n- 중식제공\r\n- 셔틀버스 운행 : 포천 송우리시장 - 송우리터미널 - 송우리홈플러스 - 포천터미널 - 일동터미널', 'category_name': '사무용 전자기기 설치·수리원(컴퓨터 제외)', 'certificate_name': None}
# {'recruit_id': 'K120252107060011', 'title': '(장애인만 채용) 물류센터 단순업무직(중식제공/셔틀운행)', 'content': '- 근무지: 거성디지털 물류센터(포천시 일동면 유동리 325-1)\r\n- 직무: 물류센터 통근버스 운전\r\n- 근무시간: 주 40시간(월~금, 09:00~18:00)\r\n- 급여: 월급 200 ~ 220만원 (면접 후 협의)\r\n- 셔틀버스 운행 (양주 - 포천 구간)\r\n\r\n* 동 구인은 공단에서 채용대행하고 있으며 지원방법은 이력서 이메일 제출(워크넷, 워크투게더 입사지원 불가)', 'category_name': '승합차 운전원', 'certificate_name': None}
# {'recruit_id': 'K120252107140018', 'title': '제주 특급호텔 룸메이드 모집', 'content': '제주 특급호텔에서 룸메이드를 모집합니다.\r\n\r\n&lt; 근로시간 및 조건 &gt;\r\n근로지 : 제주특별자치도 서귀포시 성산읍 동류암로 20 제주플레이스캠프 \r\n직무명 : 룸메이드\r\n근로조건 : 월 7 회휴무 / 연차별도/ 공휴일 대체휴무\r\n근무시간 : 09:00~17:00(휴게시간 : 12~13시)\r\n\r\n급여 : 200만원 이상(추가정비 수당지급)\r\n\r\n근무장소와 가까운 분만 지원해 주세요.\r\n장기 근무하실 분 우대합니다.', 'category_name': '호텔·콘도·숙박시설 청소원(룸메이드,하우스키퍼)', 'certificate_name': None}
# {'recruit_id': 'K120252107160008', 'title': '플랜트공학기술자(기계) 모집-&lt;철골, 용접감리&gt;', 'content': '1. 건축 철골감리 ; 철골제작과 현장 철골설치 감리\r\n    - 강재의 절단, 조립(취부), 용접, 도장 등의 품질관리 지식 보유자\r\n2. 플랜트 기자재감리 ; 압력용기 및 압력배관 감리\r\n    - 강재의 절단, 조립, 용접, 비파괴검사, 압력시험 등의 지식 보유자', 'category_name': '플랜트공학 기술자 및 연구원', 'certificate_name': '용접산업기사'}
# {'recruit_id': 'K120252107160008', 'title': '플랜트공학기술자(기계) 모집-&lt;철골, 용접감리&gt;', 'content': '1. 건축 철골감리 ; 철골제작과 현장 철골설치 감리\r\n    - 강재의 절단, 조립(취부), 용접, 도장 등의 품질관리 지식 보유자\r\n2. 플랜트 기자재감리 ; 압력용기 및 압력배관 감리\r\n    - 강재의 절단, 조립, 용접, 비파괴검사, 압력시험 등의 지식 보유자', 'category_name': '플랜트공학 기술자 및 연구원', 'certificate_name': '용접기사'}
# {'recruit_id': 'K120252107270006', 'title': '성동05번.06번.07번 마을버스 운행사원모집', 'content': '마을버스 운행사원\r\n\r\n[자동차운전·운송&gt;자동차운전·운송&gt;여객운송]\r\n운행 전후 차량 점검\r\n유실물 처리하기,차량 내부상태 점검하기,차량 배차현황 파악하기,차량 외부상태 점검하기\r\n\r\n[자동차운전·운송&gt;자동차운전·운송&gt;여객운송]\r\n차량운행\r\n승객 편의 제공하기,운행 법규 준수하기,차량 안전 상태 확인하기', 'category_name': '노선버스 운전원(시내, 마을, 시외, 고속)', 'certificate_name': '자동차운전면허1종대형'}
# {'recruit_id': 'K120252107270006', 'title': '성동05번.06번.07번 마을버스 운행사원모집', 'content': '마을버스 운행사원\r\n\r\n[자동차운전·운송&gt;자동차운전·운송&gt;여객운송]\r\n운행 전후 차량 점검\r\n유실물 처리하기,차량 내부상태 점검하기,차량 배차현황 파악하기,차량 외부상태 점검하기\r\n\r\n[자동차운전·운송&gt;자동차운전·운송&gt;여객운송]\r\n차량운행\r\n승객 편의 제공하기,운행 법규 준수하기,차량 안전 상태 확인하기', 'category_name': '노선버스 운전원(시내, 마을, 시외, 고속)', 'certificate_name': '버스운전자'}
# {'recruit_id': 'K120252107290021', 'title': '우리은행 서류안내/ 잔액조회 안내 &gt; 인바운드 상담직원 채용', 'content': '** 이력서 검토 후 면접 일정 안내 드립니다.\r\n     상황에 따라 화상 면접도 진행하오니 참고 바랍니다.\r\n\r\n** 업무 설명\r\n - 고객 상담(받는 전화)\r\n - 업무 내용 : 잔액조회, 서류안내, 대출이자 조회하여 안내, 우리은행 영업점 안내\r\n                    (영업 아님)\r\n                    *대출 관련 서류 및 잔액 조회하여 안내해 주는 업무이며, 영업성은 전혀 없고, 전화상담 업무입니다.\r\n** 교육 일정\r\n - 20일 교육이 진행되며 일 30,000원 총 최대 600,000원 교육비 지급', 'category_name': '콜센터 상담원(콜센터·고객센터·CS센터)', 'certificate_name': None}
# {'recruit_id': 'K120252108030001', 'title': '(주야간보호) 성수동 성수더효데이케어센터에서 간호사를 모십니다.', 'content': '데이케어센터 간호사 (간호조무사 X)\r\n- 운전가능자 우대\r\n- 주5일 근무 (월~금 5일)\r\n- 어르신 간호, 간호일지 작성, 간호 상담 등\r\n어르신들을 섬기는 마음과 성품이 가장 중요합니다.', 'category_name': '간호사', 'certificate_name': '간호사'}
# {'recruit_id': 'K120252108030015', 'title': '한국교원대학교 내 BTL기숙사 시설관리/전기기사 채용', 'content': 'BTL 연수원기숙사 시설관리\r\n시설관리 소장 (전기선임 가능자)', 'category_name': '아파트 전기관리원', 'certificate_name': '전기기사'}
# {'recruit_id': 'K120252108030015', 'title': '한국교원대학교 내 BTL기숙사 시설관리/전기기사 채용', 'content': 'BTL 연수원기숙사 시설관리\r\n시설관리 소장 (전기선임 가능자)', 'category_name': '아파트 전기관리원', 'certificate_name': '전기산업기사'}
# {'recruit_id': 'K120252108030017', 'title': 'A+광진데이케어센터 요양보호사 채용', 'content': '[A+광진데이케어센터 요양보호사 채용]\r\n시간 09:00~18:00,시간협의가능/\r\n급여 1,850,000원/\r\n요양보호사 1급자격증 소지자/\r\n자동차 운전면허보통1,2종소지,실제운전가능자/\r\n인근거주자우대/\r\n이력서는 이메일(ak8100@naver.com)로 제출/', 'category_name': '시설 요양보호사(노인요양사)', 'certificate_name': '요양보호사1급'}
# {'recruit_id': 'K120252108030017', 'title': 'A+광진데이케어센터 요양보호사 채용', 'content': '[A+광진데이케어센터 요양보호사 채용]\r\n시간 09:00~18:00,시간협의가능/\r\n급여 1,850,000원/\r\n요양보호사 1급자격증 소지자/\r\n자동차 운전면허보통1,2종소지,실제운전가능자/\r\n인근거주자우대/\r\n이력서는 이메일(ak8100@naver.com)로 제출/', 'category_name': '시설 요양보호사(노인요양사)', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120252108090025', 'title': '세탁전문기업 크린토피아 단순세탁물정리', 'content': '세탁서비스 포장', 'category_name': '섬유·의복 분야 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120252108090028', 'title': '(장애인만 채용) 물류센터 셔틀버스 운전원 (중식제공/셔틀운행)', 'content': '- 근무지: 거성디지털 물류센터(포천시 일동면 유동리 325-1)\r\n- 직무: 물류센터 통근버스 운전\r\n- 근무시간: 주 40시간(월~금, 09:00~18:00)\r\n- 급여: 월급 200 ~ 220만원 (면접 후 협의)\r\n- 셔틀버스 운행 (양주 - 포천 구간) / (의정부 - 포천 구간)\r\n\r\n* 동 구인은 공단에서 채용대행하고 있으며 지원방법은 이력서 이메일 제출(워크넷, 워크투게더 입사지원 불가)', 'category_name': '관광 및 통근·통학·학원 및 기타 버스 운전원', 'certificate_name': None}
# {'recruit_id': 'K120252108100022', 'title': '성동구 마을버스 운전원 모집', 'content': '성동 02번, 14번 마을버스 운전원.\r\n-1종 대형면허+버스운전자자격 소지자(교통안전공단)\r\n-경력자우대/초보운전자-교육가능/중장년환영\r\n-1일 2교대(05:49~23:40 )/일일 8시간 교대근무\r\n-급여: 264만원~350만원\r\n-식사,간식비 제공\r\n-근거리 거주자', 'category_name': '노선버스 운전원(시내, 마을, 시외, 고속)', 'certificate_name': '자동차운전면허1종대형'}
# {'recruit_id': 'K120252108100022', 'title': '성동구 마을버스 운전원 모집', 'content': '성동 02번, 14번 마을버스 운전원.\r\n-1종 대형면허+버스운전자자격 소지자(교통안전공단)\r\n-경력자우대/초보운전자-교육가능/중장년환영\r\n-1일 2교대(05:49~23:40 )/일일 8시간 교대근무\r\n-급여: 264만원~350만원\r\n-식사,간식비 제공\r\n-근거리 거주자', 'category_name': '노선버스 운전원(시내, 마을, 시외, 고속)', 'certificate_name': '버스운전자'}
# {'recruit_id': 'K120252108120010', 'title': '(주)에코시티서울 생산직 공개 채용 재공고', 'content': '폐전기/전자제품 수작업 선별, 분해, 파쇄 업무', 'category_name': '제조 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'K120252108120013', 'title': '엔터식스 왕십리점 미화팀 모집', 'content': '엔터식스 왕십리점 미화팀 모집합니다.\r\n\r\n월급 세전 160만원대 \r\n\r\n4대보험 적용, 주 2회 휴무 (주말 근무 필수)\r\n\r\n오전 -  09:30~17:30 / 오후 - 13:30~21:30 순환근무 \r\n\r\n전화로 면접 문의 사절합니다.', 'category_name': '청소원', 'certificate_name': None}
# {'recruit_id': 'K120312107120034', 'title': '사회복지사 채용', 'content': '1. 수급자 가정 방문 및 업무수행일지\r\n2. 요양보호사 관리\r\n3. 수급자 관리\r\n4. 서류관리\r\n5. 기타/평가준비', 'category_name': '사회복지사(사회복지시설)', 'certificate_name': None}
# {'recruit_id': 'K120312107130039', 'title': '아파트 청소원', 'content': '아파트 관내 청소', 'category_name': '청소원', 'certificate_name': None}
# {'recruit_id': 'K120312107190055', 'title': '경리직원', 'content': '경리회계처리 \r\n일주일에 4시간소요', 'category_name': '총무 및 일반 사무원', 'certificate_name': None}
# {'recruit_id': 'K120312107200026', 'title': '의정부 민락2지구  기계설비 유지 자격증소지자 &#39;제일풍경채 주상복합건물&#39;', 'content': '* 의정부 민락2지구 제일 풍경채 주상복합건물 기계설비유지관리자\r\n* 근무시간 : 24시간 격일제\r\n* 급여 2,744,000원 \r\n* 면접자는  이력서 지참 \r\n* 자세한 사항은 전화 주시면  안내해드리겠습니다.(010-4753-5114 송귀영전무)\r\n* 위치 (민락2지구 중흥 S 클래식 옆입니다)\r\n* 지원자는 통화 후 관리사무소로 이력서 지참하여 오시면 됩니다.', 'category_name': '냉·난방 설비 조작원', 'certificate_name': '에너지관리기능사'}
# {'recruit_id': 'K120312107200026', 'title': '의정부 민락2지구  기계설비 유지 자격증소지자 &#39;제일풍경채 주상복합건물&#39;', 'content': '* 의정부 민락2지구 제일 풍경채 주상복합건물 기계설비유지관리자\r\n* 근무시간 : 24시간 격일제\r\n* 급여 2,744,000원 \r\n* 면접자는  이력서 지참 \r\n* 자세한 사항은 전화 주시면  안내해드리겠습니다.(010-4753-5114 송귀영전무)\r\n* 위치 (민락2지구 중흥 S 클래식 옆입니다)\r\n* 지원자는 통화 후 관리사무소로 이력서 지참하여 오시면 됩니다.', 'category_name': '냉·난방 설비 조작원', 'certificate_name': '소방설비산업기사(기계분야)'}
# {'recruit_id': 'K120312107230016', 'title': '[삼성전자 수원]  JAVA (API) 개발자 채용', 'content': 'JAVA (API) 개발자 채용 (우대사항 2년 경력 이상)', 'category_name': '응용 소프트웨어 개발자', 'certificate_name': None}
# {'recruit_id': 'K120312107260029', 'title': '불교협동조합', 'content': '일반 사무 보조', 'category_name': '사무 보조원(일반사업체)', 'certificate_name': '자동차운전면허'}
# {'recruit_id': 'K120312108100014', 'title': '한국효요양병원 방사선사 추가 구인 합니다(군필자우대/남자 기숙사 제공)/단기알바 가능', 'content': '한국효요양병원 방사선사 신입직원 추가 구인 합니다(단기알바 가능, 내일채움공제 가능, 군필자 우대/남자 기숙사 제공)\r\n\r\n1. 업무  \r\n- 현재 방사선사 1인 근무중이며 추가 신입 방사선사 구인 합니다. 단기 알바(시간조정가능)도 가능합니다.\r\n- 원무행정 및 방사선 촬영 : 요양병원 청구 및 건강보험공단 및 보건소 행정업무 숙지와 방사선 업무의 효용성이 높아질때 경험이 쌓인 부서장이 될 수 있습니다.\r\n 함께 근무하게 된다면 적정성 평가 3회차 연속 1등급(6년) 병원에서 입원상담 및 전반적인 행정 업무를 배울 수 있는 좋은 기회가 될 것입니다. \r\n- 은퇴 경력직의 경우 출근일 및 출퇴근 시간 조정 가능합니다\r\n \r\n2. 위 치  \r\n- 서울 은평구 응암동 상현빌딩\r\n\r\n3. 근무시간 :   \r\n- (월-금) 09~18시\r\n- 월 1~2회 주말 당직(09~18시)\r\n\r\n4. 급여 및 복리\r\n- 남자의 경우 기숙사 무료 제공\r\n- 급여 협의  \r\n- 4대보험, 퇴직금\r\n\r\n5. 우대요건  \r\n- 군필/방사선사 면허\r\n\r\n6. 지원방법  \r\n- 이메일 : day1008@hanmail.net \r\n\r\n7. 문의사항 \r\n- 이성진 과장(010.3430.6067)', 'category_name': '방사선사', 'certificate_name': '방사선사'}
# {'recruit_id': 'K120312108100020', 'title': '프랜차이즈 메뉴바이저 채용공고', 'content': '1. 신규 가맹점 조리교육\r\n2. 가맹점 실무지도 및 지원\r\n3. 주기적인 신메뉴 개발 및 상품 기획\r\n4. 주기적인 기존 메뉴 업그레이드\r\n5. 문서관리(레시피, 원가표 등)\r\n6. 전용 식자재 개발 및 개선\r\n7. 브랜드 이해를 위해 직영점 약 1년 수료 후 본사 근무 (근무평가 및 회사 사정에 따라 변경될 수 있음)\r\n\r\n[한식조리 &amp;gt; 한식 면류조리]\r\n면류 재료 준비하기,면류 조리하기,면류 담기\r\n\r\n[한식조리 &amp;gt; 한식 국 · 탕조리]\r\n국·탕 재료 준비하기,국·탕 조리하기,국·탕 담기\r\n\r\n[한식조리 &amp;gt; 한식  찜 · 선조리]\r\n찜·선 재료 준비하기,찜·선 조리하기,찜·선 담기\r\n\r\n[한식조리 &amp;gt; 한식 메뉴관리]\r\n메뉴관리 계획하기,메뉴 개발하기,메뉴원가 계산하기\r\n\r\n[한식조리 &amp;gt; 한식구매관리]\r\n시장 조사하기,구매 관리하기,검수 관리하기', 'category_name': '한식 조리사', 'certificate_name': '한식조리기능사'}
# {'recruit_id': 'K120312108100020', 'title': '프랜차이즈 메뉴바이저 채용공고', 'content': '1. 신규 가맹점 조리교육\r\n2. 가맹점 실무지도 및 지원\r\n3. 주기적인 신메뉴 개발 및 상품 기획\r\n4. 주기적인 기존 메뉴 업그레이드\r\n5. 문서관리(레시피, 원가표 등)\r\n6. 전용 식자재 개발 및 개선\r\n7. 브랜드 이해를 위해 직영점 약 1년 수료 후 본사 근무 (근무평가 및 회사 사정에 따라 변경될 수 있음)\r\n\r\n[한식조리 &amp;gt; 한식 면류조리]\r\n면류 재료 준비하기,면류 조리하기,면류 담기\r\n\r\n[한식조리 &amp;gt; 한식 국 · 탕조리]\r\n국·탕 재료 준비하기,국·탕 조리하기,국·탕 담기\r\n\r\n[한식조리 &amp;gt; 한식  찜 · 선조리]\r\n찜·선 재료 준비하기,찜·선 조리하기,찜·선 담기\r\n\r\n[한식조리 &amp;gt; 한식 메뉴관리]\r\n메뉴관리 계획하기,메뉴 개발하기,메뉴원가 계산하기\r\n\r\n[한식조리 &amp;gt; 한식구매관리]\r\n시장 조사하기,구매 관리하기,검수 관리하기', 'category_name': '한식 조리사', 'certificate_name': '양식조리기능사'}
# {'recruit_id': 'K120312108110010', 'title': 'GS건설 공사현장(인천 용현자이) 경비원 채용', 'content': '1. 업무 내용 : GS건설 인천 용현자이\r\n\r\n2. 근무 위치 : 인천 미추홀구 용현동 535-20 GS건설 용현자이 현장\r\n\r\n3. 급여 조건 : 2,538,000 원(세전) 이상\r\n\r\n4. 자격 요건 : 경비이수자 필수, 공사장 현장경비 경험 필수\r\n\r\n5. 근무기간 :  1년 이상 ( 3개월 근무평가 기간 )\r\n6. 지원 서류 : 이력서 1부 (필수)   FAX 02-318-4159 \r\n\r\n7. 근무 시간:  격일경비 06:30 ~ 익일 06:30(상황에 따라 주간으로 변경할 수도 있음)', 'category_name': '공사현장 경비원', 'certificate_name': None}
# {'recruit_id': 'K120312108110018', 'title': '건설현장경비원(경북포항)', 'content': '건설현장 게이트 근무  공사 차량 입 출입 관리, 방문객 관리 ,도난 사고 관리 , 순찰 등등', 'category_name': '공사현장 경비원', 'certificate_name': None}
# {'recruit_id': 'K120312108110046', 'title': 'GS건설 공사현장 보라매자이 주간 경비대원 채용', 'content': '1. 업무 내용 : GS건설 보라매자이 건설현장 경비원\r\n\r\n2. 근무 위치 : 서울 동작구 신대방동 355-30\r\n\r\n3. 급여 조건 : 2,538,000 원(세전) 이상\r\n\r\n4. 자격 요건 : 경비이수자 필수, 공사장 현장경비 경험 필수\r\n\r\n5. 근무기간 :  1~2 개월\r\n\r\n6. 지원 서류 : 이력서 1부 (필수)   FAX 02-318-4159 \r\n\r\n7. 근무 시간\r\n   - 주간경비 1명: 06:30 ~ 17:00(휴게시간 2시간)', 'category_name': '공사현장 경비원', 'certificate_name': None}
# {'recruit_id': 'K120312108110054', 'title': '용산구 (주)태영교통 버스정비원 모집', 'content': '- 마을버스 카운티 정비사 (1종대형면허소지자, 버스운전자격증 소지자) 경력자우대', 'category_name': '자동차 정비원', 'certificate_name': '버스운전자'}
# {'recruit_id': 'K120312108110054', 'title': '용산구 (주)태영교통 버스정비원 모집', 'content': '- 마을버스 카운티 정비사 (1종대형면허소지자, 버스운전자격증 소지자) 경력자우대', 'category_name': '자동차 정비원', 'certificate_name': '자동차운전면허1종대형'}
# {'recruit_id': 'K120412106230005', 'title': 'GS송파물류센터(서울복합물류) 외부지게차 근무자 모집', 'content': '업무내용 : GS송파물류센터(서울복합물류) 외부지게차 업무(상품하차및 파렛트정리)\r\n\r\n우대사항 : 지게차 조종 면허 또는 지게차조종 교육이수자(관련 자격증 이수증 필수) \r\n\r\n근무요일 주 6일 (월~토,일 휴무) \r\n\r\n근무시간 07:00~16:.00\r\n\r\n근무기간 1년 이상 희망 \r\n\r\n급여 월급 : 2,525,625 *휴일근로 수당 별도지급*(기본급 외 연차수당, 기타수당 포함 금액입니다.) \r\n\r\n**주간 업무로 인해 통화가 어려우니 저녁 6시 이후 연락 바랍니다.**\r\n**주간 업무로 인해 통화가 어려우니 저녁 6시 이후 연락 바랍니다.**\r\n**주간 업무로 인해 통화가 어려우니 저녁 6시 이후 연락 바랍니다.**\r\n\r\n지원방법 본사 : 02-3664-3567\r\n담당 박상진과장 : 010-5845-2237 1차 연락으로 문자주시기 바라며 문자 주실때 성함, 나이, 사시는곳, 지원하시고자 하는 지역,본인사진 이렇게 5개 사항을 문자로 보내주시면 취합후 연락 드리겠습니다\r\n(예 : 홍길동, 26세, 올림픽선수촌 아파트, 지원사항 : 물류센터 지게차 지원)', 'category_name': '지게차 운전원', 'certificate_name': None}
# {'recruit_id': 'K120412106230007', 'title': '경비', 'content': '아파트 경비\r\n06:00~06:00\r\n휴게시간 11:00~13:00/17:00~19:00/23:00~06:00', 'category_name': '아파트·빌라 경비원', 'certificate_name': None}
# {'recruit_id': 'K120412107210007', 'title': 'GS Fresh Mall 온라인센터 김포고촌 복합 물류단지내 강서센터(통근버스 운행)', 'content': 'GS 온라인쇼핑몰 (김포고촌 복합 물류단지내)에서 근무하실 정규 사원을 모집합니다\r\n업무내용 : 온라인 주문 배송상품을 운반,분류 \r\n   - 단순 업무라 힘들지 않고 누구나 할 수 있는 업무입니다\r\n   - 박스 등 물건을 옮기는 작업이 있어 신체활동에 무리가 없는 분\r\n   - 언어소통 가능하며, 한글 읽기가 가능한 F2,F5,F6 지원가능\r\n   - 새터민 우대\r\n   -근무일 : 주 5일 근무(스케쥴근무,주중/주말 변동 휴무실시) \r\n\r\n# 1. 조출조 사원 모집(3~4명)\r\n근무시간 : 06:00 ~ 15:00\r\n매일 교통비 4,500원 별도지급(통근버스 운행 안함)+3개월이후 일별 7000원\r\n근무일 : 주 5일 근무(주중/주말 변동 휴무실시)\r\n\r\n# 2. 주간A조 남, 여사원 모집\r\n근무시간 : 07:00~16:00\r\n통근버스 운행 출, 퇴근\r\n근무일 : 주 5일 근무(주중/주말 변동 휴무실시) \r\n\r\n# 3. 주간B조 남, 여사원 모집\r\n근무시간 : 09:30~18:30\r\n통근버스 운행 출, 퇴근\r\n근무일 : 주 5일 근무(주중/주말 변동 휴무실시) \r\n \r\nA,B조 급여 및 연차수당\r\n - 기본급여 : 1,823,000 원\r\n - 연차수당 : 68,000원\r\n - 3개월이상 근무시 4만원 추가 지급 + 주간조 일별 3,800원 추가\r\n - 중식제공\r\n - 매주 일요일 특식 제공\r\n # 당사의 &quot;고정 급여&quot;는 연장/특근/장기축하금이 발생하지 않고 기본 업무만 하여도 발생하는 급여입니다\r\n  타사 광고에 연장/특근을 하여야만 지급되는 금액과 혼동하지 않으시길 바랍니다 \r\n\r\nA,B조 연장 근무시\r\n - 시간 13,080 원 (시급X 1.5배)\r\n\r\n퇴직금 및 4대보험 등 법적사항 당연 준수합니다\r\n\r\n\r\n통근버스 정류장\r\n서울 : 화곡역/송정역/개화역/화정역\r\n인천 : 부평역/부평구청/계양역/고촌역\r\n\r\n\r\n기타 자세한 사항 언제든지 유선 바랍니다', 'category_name': '쇼핑몰택배 준비원', 'certificate_name': None}
# {'recruit_id': 'K120412107260009', 'title': '롯데마트 익산점 주차 정산원 모집(유경험자 우대)', 'content': '업무내용 : 무인주차 시스템 이용 고객에게 이용안내 및 고객응대, 주차안내 주차장 관리\r\n\r\n우대사항 : 동종업계 유경험자 (우대), 신입, 인근지역 거주자\r\n\r\n근무요일 주 5일 (평일, 마트 휴점시 휴뮤) \r\n\r\n근무시간 주간 : 11:00~21:00\r\n\r\n근무기간 1년 이상 희망 \r\n\r\n급여 월급 : 1,909,680  (기본급 외 기타수당 포함 금액입니다.) \r\n\r\n지원방법 본사 : 02-3664-3567\r\n담당 김종록 과장 : 010-4968-2045\r\n1차 연락으로 문자주시기 바라며 문자 주실때 성함, 나이, 사시는곳, 지원하시고자 하는 지역,본인사진 이렇게 5개 사항을 문자로 보내주시면 취합후 연락 드리겠습니다\r\n(예 : 홍길동, 26세, 올림픽선수촌 아파트, 지원사항 : 강동웨딩홀  주차장 관리 행사 )', 'category_name': '요금 정산원(주차요금,통행료)', 'certificate_name': None}
# ...
# {'recruit_id': 'KJRA002108090007', 'title': '[킹덤플랜트협동조합] 회계 및 사무원 모집', 'content': '▶ 직무내용 : 회계 및 매입매출 관리, 자금 관리, 결산 등의 업무를 수행\r\n▶ 자격요건 : 신입지원 가능,  해당직무 근무경험자 우대\r\n▶ 근로조건    \r\n   - 주 5일 근무 / 09:00~18:00\r\n   - 월급 183만원 이상(임금협의가능-경력과 능력에 따른 차등지급)\r\n▶ 제출서류 : 이력서(워크넷이력서-사진등록), 자기소개서   \r\n▶ 지원방법 : 워크넷 구직신청 후 [워크넷 입사지원]      \r\n\r\n※ 제출서류 중 일부 미제출시 서류전형에 불리하게 작용할 수 있습니다.   \r\n※ 구직활동 인정을 위한 입사지원은 지양해 주시길 바랍니다.   \r\n※ 불합격자에 대해서는 별도 통지를 하지 않습니다.  \r\n\r\n--------------------------------------\r\n\r\n▶ 2021. 08. 19.(목) 『안동 일자리 잡(JOB)는 날』 행사 참가 기업 \r\n  ■ 행사일시 : 2021. 08. 19.(목)  13:00 ~ (면접완료 후 귀가) \r\n  □ 면접장소 : 커피킹덤 본점 2층(경북 안동시 광명로 151)\r\n  □ 참가대상 : 경북도내 취업을 준비하고 있는 구직자 – 서류(이력서 및 자기소개서)합격자  \r\n  □ 주최/주관 : 경상북도, (재)경상북도경제진흥원 경북일자리종합센터\r\n  □ 채용관련 문의사항은 (054-470-8588)로 전화주세요~^^', 'category_name': '회계 사무원(일반 사업체)', 'certificate_name': None}
# {'recruit_id': 'KJRA002108090008', 'title': '[킹덤플랜트협동조합] HACCP(해썹) 식품연구원 모집', 'content': '▶ 직무내용 : haccp관리, 식품 연구원 등의 업무\r\n▶ 자격요건 : 신입지원 가능,  해당직무 근무경험자 우대\r\n▶ 근로조건    \r\n   - 주 5일 근무 / 09:00~18:00\r\n   - 월급 183만원 이상(임금협의가능-경력과 능력에 따른 차등지급)\r\n▶ 제출서류 : 이력서(워크넷이력서-사진등록), 자기소개서   \r\n▶ 지원방법 : 워크넷 구직신청 후 [워크넷 입사지원]      \r\n\r\n※ 제출서류 중 일부 미제출시 서류전형에 불리하게 작용할 수 있습니다.   \r\n※ 구직활동 인정을 위한 입사지원은 지양해 주시길 바랍니다.   \r\n※ 불합격자에 대해서는 별도 통지를 하지 않습니다.  \r\n\r\n--------------------------------------\r\n\r\n▶ 2021. 08. 19.(목) 『안동 일자리 잡(JOB)는 날』 행사 참가 기업 \r\n  ■ 행사일시 : 2021. 08. 19.(목)  13:00 ~ (면접완료 후 귀가) \r\n  □ 면접장소 : 커피킹덤 본점 2층(경북 안동시 광명로 151)\r\n  □ 참가대상 : 경북도내 취업을 준비하고 있는 구직자 – 서류(이력서 및 자기소개서)합격자  \r\n  □ 주최/주관 : 경상북도, (재)경상북도경제진흥원 경북일자리종합센터\r\n  □ 채용관련 문의사항은 (054-470-8588)로 전화주세요~^^', 'category_name': '식품공학 기술자 및 연구원', 'certificate_name': None}
# {'recruit_id': 'KJRB002108090001', 'title': '(주)세기리텍 제련공정 생산직 사원모집', 'content': '납 제련 공정 업무\r\n* 신입 무관하게 지원가능\r\n* 연봉 4,000만원 (상여금 기본급 기준 400% 포함)\r\n\r\n\r\n**상세 근무시간\r\n납 제련 공정업무 : 주간 07:30 ~16:30 / 오후 15:30~00:30 / 야간 23:30~8:30 (4조3교대)\r\n\r\n\r\n- 워크넷에서 구직신청(필수)후 워크넷입사지원 하시면 됩니다. -', 'category_name': '제조 단순 종사원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'KJRB002108090001', 'title': '(주)세기리텍 제련공정 생산직 사원모집', 'content': '납 제련 공정 업무\r\n* 신입 무관하게 지원가능\r\n* 연봉 4,000만원 (상여금 기본급 기준 400% 포함)\r\n\r\n\r\n**상세 근무시간\r\n납 제련 공정업무 : 주간 07:30 ~16:30 / 오후 15:30~00:30 / 야간 23:30~8:30 (4조3교대)\r\n\r\n\r\n- 워크넷에서 구직신청(필수)후 워크넷입사지원 하시면 됩니다. -', 'category_name': '제조 단순 종사원', 'certificate_name': '로더운전기능사'}
# {'recruit_id': 'KJRC002107090002', 'title': '[경주시 문무대왕면] 재가요양보호사모집*채용대행 경주시취업지원센터*', 'content': '온유재가복지센터\r\n경주시 문무 대왕면 권이길\r\n80대 초반 4등급 여자어르신\r\n경력 6개월 이상, 9~12시(3시간/주15시간)\r\n시급:11,100원\r\n문의:054-742-4426\r\n-경주시취업지원센터-\r\n*채용대행 업체 입니다. 지원을 희망하시는 분은 워크넷 구직등록 후 경주시취업지원센터 bmbo6571@naver.com 지원바랍니다*', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJRC002107120003', 'title': '화수브루어리(수제맥주) 경주점 주방 및 홀직원 구인', 'content': '화수브루어리 경주점\r\n\r\n경북 경주시 보문로 465-67 A동 1층 101호\r\n\r\n\r\n주방 1명 : 월~목 16~23시, 금~일 11~23시(금~일 포함하여 주5-6일 등의 협의 가능)\r\n\r\n홀 서빙 1명 : 위의 내용과 상동\r\n\r\n200만원\r\n\r\n홀 서빙 주말  1명 : 금~일 17~23시 시간당 9000원', 'category_name': '한식 조리사(일반 음식점)', 'certificate_name': None}
# {'recruit_id': 'KJRC002107120005', 'title': '관리사무실 (전기기사)채용** 채용대행 서비스 희망 사업장**', 'content': '-경주 보문 지티랜드 내 관리사무실 전기안전관리자 채용\r\n-전기기사+경력2년 이상/ 전기산업기사+경력4년 이상\r\n\r\n경주시취업지원센터 채용대행사업장입니다. 지원을 희망하시는 분은 워크넷 구직등록 후 입사지원 하시기 바랍니다.(문의 054-742-4426)', 'category_name': '전기안전 기술자', 'certificate_name': '전기기사'}
# {'recruit_id': 'KJRC002107120005', 'title': '관리사무실 (전기기사)채용** 채용대행 서비스 희망 사업장**', 'content': '-경주 보문 지티랜드 내 관리사무실 전기안전관리자 채용\r\n-전기기사+경력2년 이상/ 전기산업기사+경력4년 이상\r\n\r\n경주시취업지원센터 채용대행사업장입니다. 지원을 희망하시는 분은 워크넷 구직등록 후 입사지원 하시기 바랍니다.(문의 054-742-4426)', 'category_name': '전기안전 기술자', 'certificate_name': '전기산업기사'}
# {'recruit_id': 'KJRC002107230001', 'title': '상가건물청소 경력직 채용** 채용대행 서비스 희망 사업장**', 'content': '-경주시 보문로 465-67 소재\r\n-업무내용: 상가건물청소 \r\n-근무시간:08:00~12:00/토 8시간,일 4시간 근무/평일 주 1회 휴무(주6일)\r\n-급여조건:시급 8,720원(교통비 100,000원) \r\n\r\n경주시취업지원센터 채용대행사업장입니다. 지원을 희망하시는 분은 워크넷 구직등록 후 입사지원 하시기 바랍니다.(문의 054-742-4426)', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJRC002107230002', 'title': '병원구내식당 주방찬모 모집** 채용대행**', 'content': '-경주시 보문로 465-67 소재\r\n-업무내용: 병원 구내식당 주방 조리 업무\r\n-근무시간:07:00~18:00/휴게시간 14:00~16:00(주5일 근무)\r\n-급여조건:월 220만원(교통비 포함)\r\n\r\n경주시취업지원센터 채용대행사업장입니다. 지원을 희망하시는 분은 워크넷 구직등록 후 입사지원 하시기 바랍니다.(문의 054-742-4426)', 'category_name': '주방 보조원', 'certificate_name': None}
# {'recruit_id': 'KJRG002107080004', 'title': '치매교육 이수하신 요양보호사 채용_김천시취업지원센터 채용대행', 'content': '* 재가 요양보호사 채용_치매교육 이수자 필수\r\n\r\n- 근무지 :어모면 외 \r\n- 치매교육이수 필수\r\n- 09:00~12:00(시간조절가능)\r\n- 일상생활지원 가사지원 , 인지교육등\r\n- 교육 이수 수당 매일 5,760원 지급 \r\n- 요양보호사 자격증+치매교육 이수증 제출\r\n\r\n* 증명사진 첨부된 이력서 제출바랍니다. (kccenter007@naver.com) \r\n* 기타 문의사항은 김천시 취업지원센터 054)439-5524으로 연락주세요  \r\n* 실업급여 수급을 위한 형식적인 지원일 경우 담당자에게 통보되니 유의하시기 바랍니다.', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJRG002107090002', 'title': '자동차부품 제조업 영업부 경력사원 모집_김천시취업지원센터 채용대행', 'content': '[ 현대자동차 아산공장에 자동차 부품을 납품하고 있는 2차 협력사]\r\n\r\n* 자동차 부품 제조업 영업부 경력사원 모집 (소음용 머플러 생산 업체)\r\n\r\n- 업무 : 제품 납품 관리, 재고관리, 거래처관리, 월판매계획수립, 그외 영업 관리 업무 전반 \r\n- 근무시간 : 08:00~17:00/ 주5일\r\n- 급여 : 연봉 3천300만원~3천600만원\r\n- 경력 5년이상 희망 \r\n- 운전가능자, 컴퓨터 활용우수자 희망 \r\n- 월 우수사원 포상 있음 \r\n\r\n* 궁금하신 사항은 김천시취업지원센터 054) 439-5524으로 연락바랍니다. \r\n* 증명사진 첨부된 이력서 제출바랍니다. (kccenter007@naver.com)\r\n* 실업급여 수급을 위한 형식적인 지원일 경우 담당자에게 통보되니 유의하시기 바랍니다.', 'category_name': '자동차부품 및 운송장비 기술영업원', 'certificate_name': None}
# {'recruit_id': 'KJRG002108050002', 'title': '◈자동차부품생산 용접원 모집', 'content': '&amp;lt;&amp;lt;(주)브라운에프엔비 용접원  채용&amp;gt;&amp;gt; \r\n\r\n▶ 직무내용\r\n- 전기차 배터리팩케이스(BPC) 생산라인 업무(용접/사상)/아크,티그용접가능자\r\n- 2교대(주간 08:00~17:00 / 야간 20:00~익일05:00)\r\n- 주 2회 연장(2시간), 토요일 특근 8시간\r\n- 명절 상여금 10만원(1회) / 연말 상여금 100%\r\n- 만근수당 5만원(월) / 장기근속축하금 20만원(3개월 근속시 최초 2회까지)\r\n- 주52시간 근무 기준 약 290만원 이상(세전)\r\n- 신입 / 경력 무관\r\n- 통근버스(율곡~백옥 시내 전지역 운행), 기숙사 있음', 'category_name': '전기용접원(아크,알곤,티그용접원)', 'certificate_name': None}
# {'recruit_id': 'KJRG002108120002', 'title': '자동차부품 생산직 사원 모집', 'content': '- 김천시 어모면 산업단지1로 75\r\n- 자동차 부품 생산직 업무\r\n- 용접가능자 우대\r\n- 주 5일 2교대 근무 (08:00~17:00, 20:00~익일 05:00)\r\n- 시급 8,830원, 상여금 별도 지급 100%(연말),만근수당,근속수당지급\r\n- 주 2회 연장 (2시간), 토요일 특근 있음\r\n- 주야교대근무시 세전 약 289만원\r\n- 주 52시간 준수\r\n- 주야교대 근무 가능자 지원 \r\n- 신입 / 경력 무관\r\n- 통근버스, 기숙사 있음', 'category_name': '자동차 부품 조립·검사원', 'certificate_name': '지게차운전기능사'}
# {'recruit_id': 'KJRG002108120002', 'title': '자동차부품 생산직 사원 모집', 'content': '- 김천시 어모면 산업단지1로 75\r\n- 자동차 부품 생산직 업무\r\n- 용접가능자 우대\r\n- 주 5일 2교대 근무 (08:00~17:00, 20:00~익일 05:00)\r\n- 시급 8,830원, 상여금 별도 지급 100%(연말),만근수당,근속수당지급\r\n- 주 2회 연장 (2시간), 토요일 특근 있음\r\n- 주야교대근무시 세전 약 289만원\r\n- 주 52시간 준수\r\n- 주야교대 근무 가능자 지원 \r\n- 신입 / 경력 무관\r\n- 통근버스, 기숙사 있음', 'category_name': '자동차 부품 조립·검사원', 'certificate_name': '용접기능사'}
# {'recruit_id': 'KJRJ002108020001', 'title': '경비원 구인', 'content': '경비원 업무 (파지, 단지 청소, 순찰 등)\r\n\r\n경비원 신임교육 이수자만 지원 가능', 'category_name': '아파트·빌라 경비원', 'certificate_name': None}
# {'recruit_id': 'KJRM002108050001', 'title': '수산물 손질 및 건조직원 구인', 'content': '수산물(물가자미) 건조 등 단순노무', 'category_name': '어패류(수산물) 가공기계 조작원', 'certificate_name': None}
# {'recruit_id': 'KJRP002107120001', 'title': '생산직 (과채주스 착즙,충진,포장 등)', 'content': '* 업무 : 생산직 (과채주스 착즙,충진,포장 등)\r\n* 근무시간 : 주5일 / 2교대 / 일주일씩교대 (02:00~08:00  / 08:30~17:30)\r\n* 급여 : 시급(일일 8시간 근무로 책정/임금 협의)\r\n* 접수방법 : 이력서 메일(honest8733@naver.com) 제출 \r\n* 문의 : 조민정 대리 / 054-335-8732', 'category_name': '제조 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJRP002107160001', 'title': '(주)삼세(도축장)- 5톤 냉동 탑차 등 축산물 수송,운송기사 모집', 'content': '* 5톤 냉동탑차로 지육배송', 'category_name': '화물차·특수차 운전원', 'certificate_name': None}
# {'recruit_id': 'KJRX002106290001', 'title': '포항 CGV(영화관) 미화근무자 모집', 'content': '-영화관 오픈 전 마감청소 \r\n-주6일 근무 (평일 1회 휴무) \r\n\r\n-지원방법: 문자지원', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJRX002108040004', 'title': '골프장 직원 모집 (골프백 하차 및 미화)', 'content': '■ 골프백 하차 및 미화\r\n■ 중식 제공\r\n■ 주5일, 평일2일 휴무\r\n■ 골프백 무게가 있으니 신체 건강하신 분 ,군필자, 장년층 우대\r\n\r\n**실업급여 인정을 위한 입사지원은 삼가주시기 바랍니다.(실제 근무의사 있으신 분만 지원)**', 'category_name': '기타 서비스 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJRX002108110001', 'title': '[포항 북구 흥해읍 용한리] 포스코SPS 직원식당 조리원 모집', 'content': '조리\r\n\r\n\r\n[식음료조리·서비스&amp;gt;음식조리&amp;gt;한식조리]\r\n한식  구이조리\r\n구이 담기,구이 재료 준비하기,구이 조리하기\r\n\r\n[식음료조리·서비스&amp;gt;음식조리&amp;gt;한식조리]\r\n한식 국 · 탕조리\r\n국·탕 담기,국·탕 재료 준비하기,국·탕 조리하기\r\n\r\n[식음료조리·서비스&amp;gt;음식조리&amp;gt;한식조리]\r\n한식 전 ·적조리\r\n전·적 담기,전·적 재료 준비하기,전·적 조리하기\r\n\r\n[식음료조리·서비스&amp;gt;음식조리&amp;gt;한식조리]\r\n한식위생관리\r\n개인위생 관리하기,식품위생 관리하기,주방위생 관리하기', 'category_name': '단체 급식 보조원', 'certificate_name': None}
# {'recruit_id': 'KJRX002108120001', 'title': '현장노무직 구함', 'content': '- 관공서 관로 공사의 현장노무\r\n-운전면허 1종 필수(운전가능자)\r\n-장기 근속하실 분을 모십니다.', 'category_name': '건설·채굴 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJSE002107200003', 'title': '캐드사무원 모집', 'content': '오토캐드 도면 제작, 해석\r\n상여금 200% 지급', 'category_name': '기계·금속 제도사(캐드원)', 'certificate_name': '전자캐드기능사'}
# {'recruit_id': 'KJSE002107200004', 'title': '제관 및 용접 사상 직원 채용', 'content': '제관 용접 및 사상 (제품용접)\r\n보너스 200% 지급', 'category_name': '제관원', 'certificate_name': None}
# {'recruit_id': 'KJSE002107220002', 'title': '각종 철강재 운송 및 정리정돈', 'content': '납품 운전원(5톤운전)', 'category_name': '배송·납품 운전원(납품영업 포함)', 'certificate_name': None}
# {'recruit_id': 'KJSE002107220005', 'title': '주방 조리원(찬모) 모집', 'content': '- 한방 오리백숙 전문점 주방근무 찬모 모집\r\n- 김해시 삼계동 장애인복지관 밑 위치(네이버 검색 : 김해 금동가, 삼계 금동가)\r\n- 주6일 10:00 ~22:00 (월요일 휴무)\r\n- 문의 055-311-7890, 010-3877-4770\r\n-숙식제공 가능', 'category_name': '한식 조리사(일반 음식점)', 'certificate_name': None}
# {'recruit_id': 'KJSE002108030001', 'title': '[급구] 김해 경원종합건설 건물 미화원 모집', 'content': '건물 내 지정된 구역 청소 실시\r\n - 지정된 구역 내 오염된 곳 청소', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJSE002108040002', 'title': '[율하]아파트 청소원 채용합니다', 'content': '율상마을 푸르지오3단지\r\n* 아파트 청소업무 (월1회 정기휴무 있음)\r\n* 9월 1일 출근예정', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJSE002108060001', 'title': '[삼계동] 재가요양보호사', 'content': '-근무장소: 삼계동 부영2차아파트\r\n-대상자 :  2등급 80대 남자어르신(할머니와 함께 거주)\r\n-근무내용 :동네한바퀴산책(전동휠체어를 할아버지께서 직접운전잘하심), 산책후 옷갈아입히기, 몸닦기,족욕하기, 간식드리기, 거실에서 부축하여 걷기(산책없는날) 수급자옷, 침구류세탁, 소변기세척하기, 수급자이용하는 방과 거실청소.\r\n-특이사항 : 요양보호사 선생님의 성격이 활발하고 밝으신분이어야함. 두분의 어르신과 말벗. 특히 말수가 적고 조용하신 할머니와 친분을 잘 쌓으실수 있는 분, 할아버지께서 할머니의 의견을 자주 물어보시기때문.\r\n-근무시간: 주5일3시간 근무 오후 1시30~4시 30분(시간변동안됨)', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사1급'}
# {'recruit_id': 'KJSE002108090001', 'title': '병원 미화원 모집', 'content': '- 병원내 실내청소', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJSE002108100001', 'title': '완성 세탁물 검사 및 포장 작업원 모집', 'content': '1.호텔 및 콘도 등에서 사용 후 세탁 완료된 린넨류(타월류,침대시트,이불커버,패드 등) 의 검사 및 포장 작업\r\n2. 주 5일 근무 기준이며 연장이나 휴일 근무 시 별도 법정 추가 수당 지급\r\n3. 근무시간 : 08:00~17:00\r\n4. 주말에 업무량이 많기 때문에 주로 평일에 휴무 합니다(주말에 고정적으로 휴무 해야 하는 분 지원 불가)', 'category_name': '섬유·의복 분야 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJSE002108100005', 'title': '재가요양보호사 모집', 'content': '- 효사랑재가복지센터/삼계동 현대아이파크아파트\r\n- 4등급 할머니(80대),독거\r\n-식사준비,일상가사지원,말벗 등\r\n- 주 3일,14:00~17:00\r\n- 시급 : 11,000원이상\r\n- 전화 상담 후  면접\r\n- 채용담당자: 051-724-3232', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSE002108120001', 'title': '아파트 미화원모집', 'content': '아파트 청소\r\n*계약기간 2개월\r\n*관리사무소 방문지원(055-314-5560)', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KJSK002106230001', 'title': '양산집단에너지 건설현장 안전감시단 모집', 'content': '작업전 근로자 안전교육 실시\r\n개인보호구 착용 상태 관리\r\n근로자 음주체크 및 건강점건으로 인한 불안전한 상태 근절\r\n공도구 점검 및 불량공동구의 사용금지로 인한 근로자들의 안전보장\r\n작업전 안전방법 숙지 후 계획순서에 맞는 작업 실시.\r\n작업장 내 상태점검\r\n현장내 소화기 및 방화수 구역별 배치\r\n소화기 점검유뮤 확인\r\n화재감시창 및 소방설비 배치구역 숙지\r\n단부노출지역 침 낙하물 위험지역의 통제 및 위험구역 설정', 'category_name': '건축안전·환경·품질·에너지관리 기술자', 'certificate_name': None}
# {'recruit_id': 'KJSK002107090006', 'title': '재가요양보호사구함', 'content': '-서창동 대동아파트\r\n-3등급 할머니\r\n-주6일 13:00~16:00\r\n-시급 11,000원', 'category_name': '재가 요양보호사', 'certificate_name': None}
# {'recruit_id': 'KJSK002108020001', 'title': '재가요양보호사 모집', 'content': '- 4등급 할머니 케어\r\n-월10일근무 13:00~15:00 (월,수,금 ,월,수,금 ,수,금 ,수,금 =&gt;협의 변동)\r\n-시급 11,000', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSK002108020002', 'title': '재가요양보호사 모집', 'content': '- 근무지 : 양산 덕계\r\n- 3등급 남자어르신(70대) 거동불편\r\n- 근무시간 : 13:00 ~ 16:00 (주5일)\r\n- 시급: 8,720원 (수당포함 11,000원)\r\n- 가사,청소등 일상생활지원', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSK002108100001', 'title': '재가요양보호사구함', 'content': '* [물금읍 반도유보라 거주] 3등급 할머니, 배우자 동거\r\n- 휠체어 사용, 가사지원, 주1회 목욕, 식사준비 등\r\n- 주6일(13:00~16:00)\r\n- 임금: 시급 11,200원(주휴수당 포함 금액)', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSK002108110004', 'title': '재가요양보호사 모집', 'content': '-2등급할아버지(배우자거주)\r\n-기저귀착용 / 가사지원, 식사준비등\r\n- 주5일 9:00~12:00', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSK002108120002', 'title': '하북면 재가요양보호사 모집', 'content': '* 4등급  독거 할아버지\r\n* 09:00~12:00', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSK002108120004', 'title': '재가요양보호사구함', 'content': '* [물금학산1길 주택] 3등급 할머니, 보호자출근\r\n*주5일 12:30~15:30\r\n* 시급 11,200원(주휴수당 포함 금액)\r\n*젊으신분 지원희망함.', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSM002107130001', 'title': '요양보호사 선생님 모집합니다.', 'content': '* 요양보호사 업무\r\n\r\n*5등급(치매교육 이수자)', 'category_name': '재가 요양보호사', 'certificate_name': '요양보호사'}
# {'recruit_id': 'KJSO002106280002', 'title': '생산직 사원 채용', 'content': '단순 박스 생산 및 포장', 'category_name': '제조 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJSO002106280003', 'title': '납품 기사 채용합니다.', 'content': '- 단순 배송 납품 업무\r\n- 1톤 트럭 운전\r\n- 지게차 가능자 우대', 'category_name': '배송·납품 운전원(납품영업 포함)', 'certificate_name': '자동차운전면허1종보통'}
# {'recruit_id': 'KJSO002108030001', 'title': '생산직 사원 모집합니다.', 'content': '(주)디.엠 테크는 친환경안료(보도블럭 착색제) 및 관련 제품 제조업체로 생산직 사원을 모집합니다.\r\n(인체에 무해한 안료 취급)\r\n\r\n- 분쇄, 포장업무\r\n- 근무시간 8:30 ~ 18:00 , 주 5일 (추가근무 30분은 잔업수당 지급)\r\n- 국공휴일 휴무\r\n- 창녕읍 내 통근차량 운행', 'category_name': '제조 단순 종사원', 'certificate_name': None}
# {'recruit_id': 'KJSO002108050002', 'title': '생산직 (CNC가공) 모집', 'content': '자동차부품제조 CNC 가공 (단순노무자)', 'category_name': 'CNC 선반 조작원(NC 선반 조작원)', 'certificate_name': None}
# {'recruit_id': 'KJSP002107230009', 'title': '한마음병원(신축) 조리배식원 모집', 'content': '* 모집직종 : 조리배식원 2명\r\n* 근무장소 : 한마음병원(신축)\r\n* 근무시간 : (오전) 05:00~ (오후) 15:00(1명) / (오전) 06:00~ (오후) 15:30(1명)\r\n                 (주5일 근무/ 토,일 교대 근무)\r\n* 기간정함이 있는 근로계약 종료 후 재계약 연장 검토\r\n\r\n* 경남고용안정선제대응지원센터 채용대행중입니다.\r\n* 지원방법: 워크넷, 이메일입사지원시 회사명 기재 : kefsj2020@naver.com\r\n* 문의전화 : 055-289-3855', 'category_name': '기타 음식서비스 종사원(병원 배식원)', 'certificate_name': None}
# {'recruit_id': 'KJSS002107270003', 'title': '[경남함안/칠서] 피자나라치킨공주 가맹점 납품 배송기사님  모집', 'content': '- 피자나라 치킨공주 가맹점에게 발주 물품 배송 \r\n\r\n- 08:30  출근 -&gt; 물품 확인 및 상차-&gt; 가맹점 배송-&gt; 퇴근 18:30 (장거리 운행시 지연될수있음)\r\n\r\n- 주요 납품 품목 : 피자 및 치킨 제조 관련 생지 , 치킨 기름 등 \r\n\r\n- 냉동탑차로 업무 진행 (1.2톤 스틱운전)\r\n\r\n[지원자격]\r\n\r\n- 1.2톤 냉동 스틱 탑차 운전 가능하신 분\r\n- 월~토 근무 (일요일 고정휴무, 평일중 스케줄 하루 휴무) 주5일제\r\n- 자차로 출퇴근 가능하신 분 (대중교통 이용 불가 지역)', 'category_name': '배송·납품 운전원(납품영업 포함)', 'certificate_name': None}
# {'recruit_id': 'KJSS082107280001', 'title': '[북면 감계 힐스테이트2차] 아파트 청소원 모집 합니다', 'content': '-아파트 단지내 복도,계단등 공동부분 청소\r\n  (성실하게 일하실분 문의환영합니다^^)\r\n\r\n-채용담당자 (주) 진광 이영신 055)264-0147\r\n-방문 또는 이력서 팩스지원055)264-0149', 'category_name': '건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)', 'certificate_name': None}
# {'recruit_id': 'KN50042108110003', 'title': '플라스틱용기 포장 단순직 주.야간업무  구인', 'content': '식품용기회사-포장기술자 서브업무 및 포장단순업무\r\n(주.야간 근무.가능자)-야간수당 별도\r\n오래 가족같이 일하실 성실한 분 지원바랍니다.\r\n\r\n영순면 논공단지내-통근차 없으므로 자차 운행자 우대합니다.\r\n\r\n워크넷 지원 어려우신 분 전화 주세요~~~\r\n문의: 053-565-2894 대체인력뱅크', 'category_name': '제조 단순 종사원', 'certificate_name': None}

# %%
recruit_data = pd.DataFrame(data)
recruit_data.rename(columns={"category_name":"job_name"}, inplace=True)

# %%
certificate_duplicate = recruit_data[recruit_data.duplicated('recruit_id')] # 공고 id 중복(자격증 여러 개)된 애들만 추출(처음 데이터 제외)

# %%
recruit_data = recruit_data.drop(certificate_duplicate.index.tolist()) # 공고 id 중복 행(certificate_duplicate) 제거

# %%
def add_certificate(): # 자격증 여러 개인 데이터 한 행으로 합치기
    for index1, row1 in certificate_duplicate.iterrows():
        for index2, row2 in recruit_data.iterrows():
            if(row1['recruit_id'] == row2['recruit_id']):
                certificate = row2['certificate_name'] + ', ' + row1['certificate_name']
                recruit_data.loc[index2, 'certificate_name'] = certificate
                # print(certificate, index2)

# %%
add_certificate()

# %%
recruit_data_final = recruit_data.reset_index(drop=True)

# %%
recruit_data_final
# Out:
#             recruit_id                                          title  \
# 0     DdA0022108052040  신림곰할인마트 오전(야채청과 판매 및 진열포장) 오후(계산대,배송) 심야(계산대)
# 1     DdA0402106172083                            외식업(F&B) 공유주방 지점 채용
# 2     DdA0402107212110                              (강남구) 건물관리 사무직 모집
# 3     DdA0402108062034                                     상가 관리소장 모집
# 4     DdA3202106282333                       [자곡동] 3등급 할아버지 요양보호사님 구함
# ...                ...                                            ...
# 3377  KJSO002108050002                                 생산직 (CNC가공) 모집
# 3378  KJSP002107230009                             한마음병원(신축) 조리배식원 모집
# 3379  KJSS002107270003            [경남함안/칠서] 피자나라치킨공주 가맹점 납품 배송기사님  모집
# 3380  KJSS082107280001                 [북면 감계 힐스테이트2차] 아파트 청소원 모집 합니다
# 3381  KN50042108110003                       플라스틱용기 포장 단순직 주.야간업무  구인
#
#                                                 content  \
# 0            소형 마트내 상품진열 및 판매관리(검수)를 수행.\n\n시간, 임금조건 협의
# 1     ▶업무내용\r\n▷음식조리 (식자재관리)\r\n▷픽업데스크 (주문접수, 제품포장)\...
# 2                                      사무보조, 회계보조, 건물관리
# 3     상가 관리소장\n- 전기 및 수도검침\n- 관리단 회의 자료 작성\n- 2급 소방관...
# 4     [자곡동] 3등급 할아버지 요양보호사 : 어르신케어, 간단한 집안일, 식사준비   ...
# ...                                                 ...
# 3377                             자동차부품제조 CNC 가공 (단순노무자)
# 3378  * 모집직종 : 조리배식원 2명\r\n* 근무장소 : 한마음병원(신축)\r\n* 근...
# 3379  - 피자나라 치킨공주 가맹점에게 발주 물품 배송 \r\n\r\n- 08:30  출근...
# 3380  -아파트 단지내 복도,계단등 공동부분 청소\r\n  (성실하게 일하실분 문의환영합니...
# 3381  식품용기회사-포장기술자 서브업무 및 포장단순업무\r\n(주.야간 근무.가능자)-야간...
#
#                              job_name certificate_name
# 0             소규모 매장점장(매장매니저·매장슈퍼바이저)             None
# 1                      한식 조리사(일반 음식점)             None
# 2                           분양·임대 사무원             None
# 3                             빌딩 관리소장             None
# 4                            재가 요양보호사             None
# ...                               ...              ...
# 3377            CNC 선반 조작원(NC 선반 조작원)             None
# 3378             기타 음식서비스 종사원(병원 배식원)             None
# 3379               배송·납품 운전원(납품영업 포함)             None
# 3380  건물 청소원(공공건물,아파트,사무실,병원,상가,공장 등)             None
# 3381                        제조 단순 종사원             None
#
# [3382 rows x 5 columns]
